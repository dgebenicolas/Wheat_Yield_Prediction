# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.base import clone
from sklearn.metrics import r2_score, mean_absolute_error
from sklearn.model_selection import GridSearchCV,  TimeSeriesSplit, KFold
from sklearn.model_selection import cross_val_score
import lightgbm as lgb
import optuna
import shap
from tqdm import tqdm
import warnings
import importlib
import long_term_utils
importlib.reload(long_term_utils)
from long_term_utils import ( 
    map_agrofon_to_group
)

# %%
warnings.filterwarnings("ignore")

# %%
#Loading Data for Model Training
crop_yield_df = pd.read_csv(r'new_ml_data.csv')
crop_yield_df.drop(columns=['date'], inplace=True)
crop_yield_df = crop_yield_df.sort_values(by='Year', ascending=True).reset_index(drop=True)
print(crop_yield_df.shape)
crop_yield_df.head()
# Out:
# (2516, 49)
#    Подразделение   Поле           Field_ID  Year   Area  Yield     Агрофон  \
# 0       Абайское  16254        235Абайское  2020  230.0   13.1      Стерня
# 1  Золотой колос     68  2274Золотой колос  2020  449.0   12.9  Пар чистый
# 2  Золотой колос  69П-2  2279Золотой колос  2020   93.0   12.6      Стерня
# 3  Золотой колос   70 П  2281Золотой колос  2020  332.0   19.0  Пар чистый
# 4  Золотой колос     76  2283Золотой колос  2020  260.0   10.7  Пар чистый
#
#           Культура  MAX_NDVI    6_NDVI  ...  8_vapor_pressure_deficit  \
# 0            Тризо  0.497964  0.259751  ...                  0.899491
# 1  Урало-Сибирская  0.706052  0.400413  ...                  0.905292
# 2  Урало-Сибирская  0.678590  0.426735  ...                  0.905292
# 3  Урало-Сибирская  0.794868  0.447238  ...                  0.905292
# 4  Урало-Сибирская  0.802729  0.376903  ...                  0.864318
#
#    DOY_min  DOY_max        bdod         cec        clay      phh2o  \
# 0      150      151  100.337298  397.188277  297.142827  67.811299
# 1      135      138   97.778689  446.412099  281.256845  66.651730
# 2      135      135   98.676440  441.562154  291.166799  65.828451
# 3      137      138   99.046297  436.128137  295.289637  66.173014
# 4      143      147   96.475710  407.573264  283.320453  66.333207
#
#          sand        silt         soc
# 0  329.994797  372.765637  704.696368
# 1  345.383682  373.249249  786.858907
# 2  336.994458  372.006070  854.671157
# 3  337.942722  366.822114  838.569593
# 4  387.585073  329.021068  758.627299
#
# [5 rows x 48 columns]

# %%
#OUTLIER REMOVAL THROUGH IQR
merged_df = crop_yield_df.copy()
def remove_outliers(df, column_name):
    Q1 = df[column_name].quantile(0.25)
    Q3 = df[column_name].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    no_outlier_df = df[(df[column_name] >= lower_bound) & (df[column_name] <= upper_bound)]

    return no_outlier_df

no_outlier_df = remove_outliers(merged_df, 'Yield')
no_outlier_df = no_outlier_df.reset_index(drop=True)

print("Shape of data before removing outliers:",crop_yield_df.shape)
print("Shape of dataframe after removing outliers:", no_outlier_df.shape)
print("Number of Wheat Crops Sown Per Year:\n", no_outlier_df['Year'].value_counts())
no_outlier_df.head(10)
# Out:
# Shape of data before removing outliers: (2516, 48)
# Shape of dataframe after removing outliers: (2472, 48)
# Number of Wheat Crops Sown Per Year:
#  Year
# 2021    588
# 2020    560
# 2023    474
# 2024    456
# 2022    394
# Name: count, dtype: int64
#    Подразделение   Поле           Field_ID  Year   Area  Yield     Агрофон  \
# 0       Абайское  16254        235Абайское  2020  230.0   13.1      Стерня
# 1  Золотой колос     68  2274Золотой колос  2020  449.0   12.9  Пар чистый
# 2  Золотой колос  69П-2  2279Золотой колос  2020   93.0   12.6      Стерня
# 3  Золотой колос   70 П  2281Золотой колос  2020  332.0   19.0  Пар чистый
# 4  Золотой колос     76  2283Золотой колос  2020  260.0   10.7  Пар чистый
# 5  Золотой колос   76 П  2284Золотой колос  2020  156.0   20.5  Пар чистый
# 6  Золотой колос     78  2287Золотой колос  2020  192.0   21.3  Пар чистый
# 7  Золотой колос   85-1  2294Золотой колос  2020   95.0   12.1  Пар чистый
# 8  Золотой колос  85а-1  2296Золотой колос  2020   59.6   12.1  Пар чистый
# 9  Золотой колос     90  2302Золотой колос  2020  271.0   11.2  Пар чистый
#
#           Культура  MAX_NDVI    6_NDVI  ...  8_vapor_pressure_deficit  \
# 0            Тризо  0.497964  0.259751  ...                  0.899491
# 1  Урало-Сибирская  0.706052  0.400413  ...                  0.905292
# 2  Урало-Сибирская  0.678590  0.426735  ...                  0.905292
# 3  Урало-Сибирская  0.794868  0.447238  ...                  0.905292
# 4  Урало-Сибирская  0.802729  0.376903  ...                  0.864318
# 5  Урало-Сибирская  0.788107  0.458994  ...                  0.907729
# 6           others  0.732348  0.357459  ...                  0.871087
# 7    Шортандинская  0.505691  0.236240  ...                  0.856418
# 8    Шортандинская  0.797783  0.306717  ...                  0.856418
# 9    Шортандинская  0.834952  0.310509  ...                  0.856696
#
#    DOY_min  DOY_max        bdod         cec        clay      phh2o  \
# 0      150      151  100.337298  397.188277  297.142827  67.811299
# 1      135      138   97.778689  446.412099  281.256845  66.651730
# 2      135      135   98.676440  441.562154  291.166799  65.828451
# 3      137      138   99.046297  436.128137  295.289637  66.173014
# 4      143      147   96.475710  407.573264  283.320453  66.333207
# 5      139      139   97.180755  445.753858  304.090551  66.108976
# 6      141      151   95.305779  454.270825  296.283327  66.653272
# 7      149      150   95.086362  423.322065  297.106839  67.335484
# 8      147      149   94.850967  419.811523  290.300823  67.159671
# 9      147      147   99.496837  396.896792  308.470312  66.980750
#
#          sand        silt         soc
# 0  329.994797  372.765637  704.696368
# 1  345.383682  373.249249  786.858907
# 2  336.994458  372.006070  854.671157
# 3  337.942722  366.822114  838.569593
# 4  387.585073  329.021068  758.627299
# 5  347.627087  348.334488  761.351872
# 6  369.746269  333.983799  821.407067
# 7  320.878194  381.808516  722.440835
# 8  331.107407  378.393827  802.212433
# 9  337.273565  354.196204  582.768661
#
# [10 rows x 48 columns]

# %%
print( "Summary of Yield", no_outlier_df['Yield'].describe())
# Out:
# Summary of Yield count    2472.000000
# mean       15.628204
# std         6.555567
# min         1.000000
# 25%        10.707500
# 50%        14.900000
# 75%        19.900000
# max        34.000000
# Name: Yield, dtype: float64

# %%
#Data 80/20 Train/Test Split For Model Training
ix_trn, ix_val = train_test_split(
    no_outlier_df.index,
    test_size=0.2,
    random_state=42,
    stratify=no_outlier_df['Year']
)
print(ix_trn.shape)
print(ix_val.shape)
ix_tst = ix_val.copy()
# Out:
# (1977,)
# (495,)

# %%
#Remove Unwanted Columns Before Model Training
pre_process_df = no_outlier_df.copy(deep=True)
features_to_remove = [
    'Подразделение',
    'Поле',
    'Field_ID',
    'Area',
    'Культура',
    '6_NDVI',
    'Year',
]
# df_2024_test = pre_process_df[pre_process_df['Year'].isin([2024])]
# ix_val_2024 = df_2024_test.index    
pre_process_df = pre_process_df.drop(columns=features_to_remove)
id_columns = no_outlier_df[['Подразделение','Поле','Field_ID']].copy()
print(pre_process_df.columns)
print(pre_process_df.shape)
pre_process_df.head(6)
# Out:
# Index(['Yield', 'Агрофон', 'MAX_NDVI', '7_NDVI', '5_relative_humidity',
#        '6_relative_humidity', '7_relative_humidity', '8_relative_humidity',
#        '5_surface_solar_radiation_downwards_sum',
#        '6_surface_solar_radiation_downwards_sum',
#        '7_surface_solar_radiation_downwards_sum',
#        '8_surface_solar_radiation_downwards_sum', '5_temperature_2m_max',
#        '6_temperature_2m_max', '7_temperature_2m_max', '8_temperature_2m_max',
#        '5_temperature_2m_min', '6_temperature_2m_min', '7_temperature_2m_min',
#        '8_temperature_2m_min', '5_total_precipitation_sum',
#        '6_total_precipitation_sum', '7_total_precipitation_sum',
#        '8_total_precipitation_sum', '5_v_component_of_wind_10m',
#        '6_v_component_of_wind_10m', '7_v_component_of_wind_10m',
#        '8_v_component_of_wind_10m', '5_vapor_pressure_deficit',
#        '6_vapor_pressure_deficit', '7_vapor_pressure_deficit',
#        '8_vapor_pressure_deficit', 'DOY_min', 'DOY_max', 'bdod', 'cec', 'clay',
#        'phh2o', 'sand', 'silt', 'soc'],
#       dtype='object')
# (2472, 41)
#    Yield     Агрофон  MAX_NDVI    7_NDVI  5_relative_humidity  \
# 0   13.1      Стерня  0.497964  0.466679            54.604540
# 1   12.9  Пар чистый  0.706052  0.634758            59.293773
# 2   12.6      Стерня  0.678590  0.604503            59.293773
# 3   19.0  Пар чистый  0.794868  0.724622            59.293773
# 4   10.7  Пар чистый  0.802729  0.724596            60.043111
# 5   20.5  Пар чистый  0.788107  0.713867            59.228981
#
#    6_relative_humidity  7_relative_humidity  8_relative_humidity  \
# 0            46.424682            50.769116            60.710184
# 1            52.547934            54.264657            60.864747
# 2            52.547934            54.264657            60.864747
# 3            52.547934            54.264657            60.864747
# 4            52.817755            54.556699            62.289575
# 5            52.503539            54.238159            60.777760
#
#    5_surface_solar_radiation_downwards_sum  \
# 0                             6.508537e+08
# 1                             6.645415e+08
# 2                             6.645415e+08
# 3                             6.645415e+08
# 4                             6.603885e+08
# 5                             6.648933e+08
#
#    6_surface_solar_radiation_downwards_sum  ...  8_vapor_pressure_deficit  \
# 0                             6.797563e+08  ...                  0.899491
# 1                             6.609843e+08  ...                  0.905292
# 2                             6.609843e+08  ...                  0.905292
# 3                             6.609843e+08  ...                  0.905292
# 4                             6.642376e+08  ...                  0.864318
# 5                             6.606226e+08  ...                  0.907729
#
#    DOY_min  DOY_max        bdod         cec        clay      phh2o  \
# 0      150      151  100.337298  397.188277  297.142827  67.811299
# 1      135      138   97.778689  446.412099  281.256845  66.651730
# 2      135      135   98.676440  441.562154  291.166799  65.828451
# 3      137      138   99.046297  436.128137  295.289637  66.173014
# 4      143      147   96.475710  407.573264  283.320453  66.333207
# 5      139      139   97.180755  445.753858  304.090551  66.108976
#
#          sand        silt         soc
# 0  329.994797  372.765637  704.696368
# 1  345.383682  373.249249  786.858907
# 2  336.994458  372.006070  854.671157
# 3  337.942722  366.822114  838.569593
# 4  387.585073  329.021068  758.627299
# 5  347.627087  348.334488  761.351872
#
# [6 rows x 41 columns]

# %%
# field_data = pd.concat([id_columns, pre_process_df], axis=1)
# test_2024_data = field_data.loc[ix_val_2024, :]
# test_2024_data.to_csv(r'test_2024.csv', index=False)

# %%
#Pre_Process Agrofon Column to group similar types of agriculture background together thus reducing the number features after one-hot encoding
pre_process_df = map_agrofon_to_group(pre_process_df)
# pre_process_df = pre_process_df.drop(columns=['Yield'])
# pre_process_df.to_csv(r'test.csv', index=False)

# %%
target = 'Yield'
numeric_features = list(pre_process_df.drop(['Агрофон', 'Yield'], axis=1).select_dtypes(include=['int64', 'float64']).columns)
categorical_features = ['Агрофон']

# %%
# Define preprocessor
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numeric_features),
        ('cat', OneHotEncoder(handle_unknown='ignore'), categorical_features)
    ])

# Fit and transform the data
preprocessed_data = preprocessor.fit_transform(pre_process_df)
numeric_feature_names = numeric_features

categorical_feature_names = preprocessor.named_transformers_['cat'].get_feature_names_out(categorical_features)
all_feature_names = numeric_feature_names + categorical_feature_names.tolist()
preprocessed_df = pd.DataFrame(preprocessed_data, columns=all_feature_names, index=pre_process_df.index)
preprocessed_df['Yield'] = pre_process_df['Yield']
preprocessed_df = preprocessed_df.drop(columns = ['Агрофон_others'])
features = [f for f in preprocessed_df.columns if f != target]
print(features)
print(preprocessed_df.shape)
preprocessed_df.head(10)
# Out:
# ['MAX_NDVI', '7_NDVI', '5_relative_humidity', '6_relative_humidity', '7_relative_humidity', '8_relative_humidity', '5_surface_solar_radiation_downwards_sum', '6_surface_solar_radiation_downwards_sum', '7_surface_solar_radiation_downwards_sum', '8_surface_solar_radiation_downwards_sum', '5_temperature_2m_max', '6_temperature_2m_max', '7_temperature_2m_max', '8_temperature_2m_max', '5_temperature_2m_min', '6_temperature_2m_min', '7_temperature_2m_min', '8_temperature_2m_min', '5_total_precipitation_sum', '6_total_precipitation_sum', '7_total_precipitation_sum', '8_total_precipitation_sum', '5_v_component_of_wind_10m', '6_v_component_of_wind_10m', '7_v_component_of_wind_10m', '8_v_component_of_wind_10m', '5_vapor_pressure_deficit', '6_vapor_pressure_deficit', '7_vapor_pressure_deficit', '8_vapor_pressure_deficit', 'DOY_min', 'DOY_max', 'bdod', 'cec', 'clay', 'phh2o', 'sand', 'silt', 'soc', 'Агрофон_Deep Tillage', 'Агрофон_Fallow', 'Агрофон_Stubble']
# (2472, 43)
#    MAX_NDVI    7_NDVI  5_relative_humidity  6_relative_humidity  \
# 0 -1.326099 -0.982386             0.635486            -0.649539
# 1  0.432387  0.305651             1.206811             0.169349
# 2  0.200310  0.073792             1.206811             0.169349
# 3  1.182944  0.994300             1.206811             0.169349
# 4  1.249377  0.994098             1.298108             0.205434
# 5  1.125810  0.911886             1.198916             0.163412
# 6  0.654609  0.395759             1.290914             0.208077
# 7 -1.260805 -3.078139             1.300672             0.219052
# 8  1.207574  0.874756             1.300672             0.219052
# 9  1.521683  1.472524             1.294239             0.205463
#
#    7_relative_humidity  8_relative_humidity  \
# 0            -1.023737             0.200754
# 1            -0.471977             0.221509
# 2            -0.471977             0.221509
# 3            -0.471977             0.221509
# 4            -0.425879             0.412841
# 5            -0.476159             0.209828
# 6            -0.431983             0.382971
# 7            -0.392955             0.448736
# 8            -0.392955             0.448736
# 9            -0.408974             0.445925
#
#    5_surface_solar_radiation_downwards_sum  \
# 0                                -0.352671
# 1                                -0.069262
# 2                                -0.069262
# 3                                -0.069262
# 4                                -0.155249
# 5                                -0.061978
# 6                                -0.144410
# 7                                -0.173981
# 8                                -0.173981
# 9                                -0.178381
#
#    6_surface_solar_radiation_downwards_sum  \
# 0                                 0.125023
# 1                                -0.419310
# 2                                -0.419310
# 3                                -0.419310
# 4                                -0.324975
# 5                                -0.429800
# 6                                -0.336412
# 7                                -0.285029
# 8                                -0.285029
# 9                                -0.274952
#
#    7_surface_solar_radiation_downwards_sum  \
# 0                                 1.071792
# 1                                 0.863055
# 2                                 0.863055
# 3                                 0.863055
# 4                                 0.857470
# 5                                 0.865263
# 6                                 0.854095
# 7                                 0.859551
# 8                                 0.859551
# 9                                 0.859761
#
#    8_surface_solar_radiation_downwards_sum  ...       cec      clay     phh2o  \
# 0                                -1.069574  ... -0.490353  0.177192  0.014679
# 1                                -0.790464  ...  0.791289 -0.517584 -0.823506
# 2                                -0.790464  ...  0.665011 -0.084170 -1.418607
# 3                                -0.790464  ...  0.523525  0.096143 -1.169542
# 4                                -0.890144  ... -0.219959 -0.427331 -1.053747
# 5                                -0.783123  ...  0.774150  0.481052 -1.215831
# 6                                -0.876099  ...  0.995907  0.139602 -0.822391
# 7                                -0.908785  ...  0.190093  0.175619 -0.329260
# 8                                -0.908785  ...  0.098689 -0.122044 -0.456345
# 9                                -0.912987  ... -0.497943  0.672602 -0.585676
#
#        sand      silt       soc  Агрофон_Deep Tillage  Агрофон_Fallow  \
# 0 -0.759879  0.879759 -0.307352                   0.0             0.0
# 1 -0.320950  0.898674  0.292374                   0.0             1.0
# 2 -0.560232  0.850050  0.787353                   0.0             0.0
# 3 -0.533185  0.647288  0.669824                   0.0             1.0
# 4  0.882740 -0.831233  0.086304                   0.0             1.0
# 5 -0.256962 -0.075823  0.106192                   0.0             1.0
# 6  0.373932 -0.637125  0.544550                   0.0             1.0
# 7 -1.019908  1.233455 -0.177830                   0.0             1.0
# 8 -0.728145  1.099895  0.404443                   0.0             1.0
# 9 -0.552271  0.153448 -1.197334                   0.0             1.0
#
#    Агрофон_Stubble  Yield
# 0              1.0   13.1
# 1              0.0   12.9
# 2              1.0   12.6
# 3              0.0   19.0
# 4              0.0   10.7
# 5              0.0   20.5
# 6              0.0   21.3
# 7              0.0   12.1
# 8              0.0   12.1
# 9              0.0   11.2
#
# [10 rows x 43 columns]

# %%
#Prepare Training and Test Splits
X_train = preprocessed_df.loc[ix_trn, features]
X_test = preprocessed_df.loc[ix_val, features]
y_train = preprocessed_df.loc[ix_trn, target]
y_test = preprocessed_df.loc[ix_val, target]
print("Shape of X_train:", X_train.shape)
print("Shape of X_test:", X_test.shape)
print("Shape of y_train:", y_train.shape)
print("Shape of y_test:", y_test.shape)
# Out:
# Shape of X_train: (1977, 42)
# Shape of X_test: (495, 42)
# Shape of y_train: (1977,)
# Shape of y_test: (495,)

# %%
params={"objective": "regression",
        "metric": "mae",
        "verbosity": -1,
        "boosting_type": "gbdt",
        "feature_pre_filter": False,
        "seed" : 42,
}

# %%
#Train LightGBM model
dtrain = lgb.Dataset(X_train, label=y_train)

lgbfit = lgb.train(params,
                   dtrain,
                   num_boost_round=100
                   )

y_pred = lgbfit.predict(X_test)

mae_log = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print(f"Mean Absolute Error (log scale): {mae_log}")
print(f"R-squared: {r2}")
print(f"Train MAE: {mean_absolute_error(y_train, lgbfit.predict(X_train))}")
print(f"R-squared: {r2_score(y_train, lgbfit.predict(X_train))}")
# Out:
# Mean Absolute Error (log scale): 2.8105305747068634
# R-squared: 0.6978342263591206
# Train MAE: 1.2525389026989142
# R-squared: 0.9357566111289646

# %%
print("Predicted Mean Yield",y_pred.mean())
# Out:
# Predicted Mean Yield 15.717488085886894

# %%
print("Test Mean Yield", y_test.mean())
# Out:
# Test Mean Yield 15.724363636363636

# %% [markdown]
#  The Mean Absolute Error of our LightGBM model is 2.81 on the testing set, which is about 18% Per Field, because the fields are scattered over a whole state with different soil, agricultural, technological conditions, the variance is very high at 6.55, thus the results of our modela are satisfactory at a field scale level. However, the model overfits heavily towards the training set, which is a problem that we will address during parameter tuning.

# %%
#Add Farm ID columns to group Mean Predicted Yield By Farm
farm_data = pd.concat([id_columns, pre_process_df], axis=1)
results_df = farm_data.loc[ix_val, :]

results_df['Predicted_Yield'] = y_pred
# print(results_df.shape)
# print(mean_absolute_error(results_df['Yield'], results_df['Predicted_Yield']))

# %%
farm_yield = results_df.groupby('Подразделение').agg({
    'Yield' : 'mean',
    'Predicted_Yield' : 'mean'
})
print("MAE Per Farm", mean_absolute_error(farm_yield['Yield'], farm_yield['Predicted_Yield']))
print("Yield Per Farm", farm_yield['Yield'].mean())
# Out:
# MAE Per Farm 0.792707260360071
# Yield Per Farm 14.995225376012021

# %% [markdown]
# The MAE on a Farm Level is thus about 0.7927 which means leads to a 5.2% error, which is quite satisfactory for Financial and Harvesting Planning.

# %%
# import plotly.express as px
# import plotly.graph_objects as go
# from scipy.stats import gaussian_kde
     
# def compute_kde(data, grid_points=1000):
#             kde = gaussian_kde(data, bw_method='scott')  # 'scott' is a rule-of-thumb bandwidth selector
#             min_val, max_val = min(data), max(data)
#             x_grid = np.linspace(min_val, max_val, grid_points)
#             kde_values = kde(x_grid)
#             return x_grid, kde_values


# # Prepare the data
# actual_yield = results_df['Yield']
# predicted_yield = results_df['Predicted_Yield']

# # Compute KDE for actual and predicted yields
# x_actual, kde_actual = compute_kde(actual_yield)
# x_predicted, kde_predicted = compute_kde(predicted_yield)

# # Create the figure with transparent fill for the KDE
# fig_kde = go.Figure()

# # Add KDE line and fill for Actual Yield
# fig_kde.add_trace(go.Scatter(
#     x=x_actual, 
#     y=kde_actual, 
#     mode='lines', 
#     name='Actual Yield',
#     line=dict(color='blue'),
#     fill='tozeroy',  # Filling to the X-axis
#     fillcolor='rgba(0, 0, 255, 0.2)'  # Transparent blue fill
# ))

# # Add KDE line and fill for Predicted Yield
# fig_kde.add_trace(go.Scatter(
#     x=x_predicted, 
#     y=kde_predicted, 
#     mode='lines', 
#     name='Predicted Yield',
#     line=dict(color='red'),
#     fill='tozeroy',  # Filling to the X-axis
#     fillcolor='rgba(255, 0, 0, 0.2)'  # Transparent red fill
# ))

# # Update layout for the plot
# fig_kde.update_layout(
#     title='Distribution Comparison: Actual vs Predicted Yield',
#     xaxis_title='Yield',
#     yaxis_title='Density',
#     template='simple_white'
# )

# fig_kde.show()

# %%
#Calculate Shapley Values to determine Feature Importance
shap_explainer = shap.TreeExplainer(lgbfit)
data=shap_explainer.shap_values(preprocessed_df[features])

# %%
shap.summary_plot(data, preprocessed_df[features], plot_size=(20 ,20), max_display=60)

# %% [markdown]
# We see that Median NDVI for a field NDVI has a very big influence on yield predictions and is a vital feature to our model, because median NDVI for July represent peak growth and vegetation of wheat during the growing season, thus it has a very strong correlation with yield. The median NDVI also helps reduce a lot of noise in the field level NDVI data. The least influential features during training where climate features such as July Wind Speed, Surface Solar Radiation, and and Deep Tilage.

# %%
#Tune HyperParameters Using Optuna
def objective(trial):
    global best_score, training_rounds

    # Specify search space for hyperparameters
    param = {
        "objective": "regression",
        "metric": "mae",
        "verbosity": -1,
        "boosting_type": "gbdt",
        "feature_pre_filter": False,
        #"force_col_wise": True,  
        # Learning rate and iterations
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.1, log=True),
        # Tree-based parameters
        "max_depth": trial.suggest_int("max_depth", 3, 10),
        "num_leaves": trial.suggest_int("num_leaves", 5, 10),
        "min_child_samples": trial.suggest_int("min_child_samples", 5, 50),
        # Regularization parameters
        "lambda_l1": trial.suggest_float("lambda_l1", 0.1, 70),
        "lambda_l2": trial.suggest_float("lambda_l2", 0.1, 70),

        # Sampling and feature selection parameters
        "feature_fraction": trial.suggest_float("feature_fraction", 0.1, 1),
        "bagging_fraction": trial.suggest_float("bagging_fraction", 0.1, 1),
        "bagging_freq": trial.suggest_int("bagging_freq", 1, 15),

        "max_cat_threshold": trial.suggest_int("max_cat_threshold", 10, 32),
        # Fixed parameters
        #"n_estimators": trial.suggest_int("n_estimators", 100, 200),
        "seed": 42
    }

    try:
        lgbfit = lgb.train(param,
                   dtrain,
                   num_boost_round = 100
                   )

        # Get predictions
        y_test_pred = lgbfit.predict(X_test)
        
        # Calculate MAEs
        test_mae = mean_absolute_error(y_test, y_test_pred)
        
        trial.set_user_attr('test_mae', test_mae)


        return test_mae

    except Exception as e:
        print(f"Trial failed with error: {str(e)}")
        return float('inf')

# %%
# Setup and run Optuna study
study = optuna.create_study(
    direction='minimize'
)

# Run optimization
study.optimize(
    objective,
    n_trials=500,  # 4 hours
    timeout = 3600,
    n_jobs=2,  # Increase if you have multiple cores available
    show_progress_bar=True
)
# Out:
# [I 2025-01-30 13:46:43,379] A new study created in memory with name: no-name-78a6be11-0147-4bac-b1a8-1ed536e42c98
#   0%|          | 0/500 [00:00<?, ?it/s]
# [I 2025-01-30 13:46:43,474] Trial 1 finished with value: 3.3148139588709724 and parameters: {'learning_rate': 0.08582404621746981, 'max_depth': 4, 'num_leaves': 6, 'min_child_samples': 26, 'lambda_l1': 61.30152981218609, 'lambda_l2': 59.66095441500643, 'feature_fraction': 0.22069256397870834, 'bagging_fraction': 0.46143415505217855, 'bagging_freq': 4, 'max_cat_threshold': 27}. Best is trial 1 with value: 3.3148139588709724.
# [I 2025-01-30 13:46:43,519] Trial 0 finished with value: 3.589368884295423 and parameters: {'learning_rate': 0.018680913368577134, 'max_depth': 10, 'num_leaves': 8, 'min_child_samples': 14, 'lambda_l1': 54.09893067808935, 'lambda_l2': 24.408555898616484, 'feature_fraction': 0.9228935476430558, 'bagging_fraction': 0.6295335224859161, 'bagging_freq': 15, 'max_cat_threshold': 24}. Best is trial 1 with value: 3.3148139588709724.
# [I 2025-01-30 13:46:43,561] Trial 2 finished with value: 3.767351860840198 and parameters: {'learning_rate': 0.02290060419577031, 'max_depth': 6, 'num_leaves': 7, 'min_child_samples': 47, 'lambda_l1': 6.387174705571338, 'lambda_l2': 41.305658557907314, 'feature_fraction': 0.16011934128182098, 'bagging_fraction': 0.6621066733168931, 'bagging_freq': 3, 'max_cat_threshold': 22}. Best is trial 1 with value: 3.3148139588709724.
# [I 2025-01-30 13:46:43,610] Trial 3 finished with value: 3.6637156722096145 and parameters: {'learning_rate': 0.022616826599291776, 'max_depth': 6, 'num_leaves': 8, 'min_child_samples': 18, 'lambda_l1': 30.948794916481138, 'lambda_l2': 55.04280239087844, 'feature_fraction': 0.590479993482435, 'bagging_fraction': 0.42122537090741174, 'bagging_freq': 14, 'max_cat_threshold': 24}. Best is trial 1 with value: 3.3148139588709724.
# [I 2025-01-30 13:46:43,762] Trial 4 finished with value: 3.586773940562523 and parameters: {'learning_rate': 0.02535939151304513, 'max_depth': 6, 'num_leaves': 10, 'min_child_samples': 40, 'lambda_l1': 46.9296017040457, 'lambda_l2': 18.813513895035335, 'feature_fraction': 0.16532689154975932, 'bagging_fraction': 0.8954426627990106, 'bagging_freq': 2, 'max_cat_threshold': 19}. Best is trial 1 with value: 3.3148139588709724.
# [I 2025-01-30 13:46:43,875] Trial 5 finished with value: 3.6258793168368832 and parameters: {'learning_rate': 0.03067015204544933, 'max_depth': 7, 'num_leaves': 10, 'min_child_samples': 26, 'lambda_l1': 69.29003200697856, 'lambda_l2': 42.760257467049875, 'feature_fraction': 0.13605007540348563, 'bagging_fraction': 0.8687049380392683, 'bagging_freq': 15, 'max_cat_threshold': 32}. Best is trial 1 with value: 3.3148139588709724.
# [I 2025-01-30 13:46:43,895] Trial 6 finished with value: 3.0009704474952987 and parameters: {'learning_rate': 0.08926373079278263, 'max_depth': 3, 'num_leaves': 10, 'min_child_samples': 39, 'lambda_l1': 7.159403100094927, 'lambda_l2': 49.37609369111401, 'feature_fraction': 0.6617162023552946, 'bagging_fraction': 0.9589003318139903, 'bagging_freq': 8, 'max_cat_threshold': 25}. Best is trial 6 with value: 3.0009704474952987.
# [I 2025-01-30 13:46:43,961] Trial 7 finished with value: 4.269355715910053 and parameters: {'learning_rate': 0.011350905003755952, 'max_depth': 10, 'num_leaves': 7, 'min_child_samples': 33, 'lambda_l1': 57.1886723152547, 'lambda_l2': 56.7231800252088, 'feature_fraction': 0.300141658926385, 'bagging_fraction': 0.5386423851296305, 'bagging_freq': 7, 'max_cat_threshold': 17}. Best is trial 6 with value: 3.0009704474952987.
# [I 2025-01-30 13:46:43,997] Trial 8 finished with value: 2.9660700030178018 and parameters: {'learning_rate': 0.0830769168207631, 'max_depth': 6, 'num_leaves': 8, 'min_child_samples': 40, 'lambda_l1': 25.42961168006523, 'lambda_l2': 39.21224972904668, 'feature_fraction': 0.5779955011261414, 'bagging_fraction': 0.9494004478944171, 'bagging_freq': 9, 'max_cat_threshold': 23}. Best is trial 8 with value: 2.9660700030178018.
# [I 2025-01-30 13:46:44,044] Trial 9 finished with value: 3.568640774144017 and parameters: {'learning_rate': 0.022741964761300863, 'max_depth': 6, 'num_leaves': 7, 'min_child_samples': 31, 'lambda_l1': 44.88673312003366, 'lambda_l2': 32.563031558258395, 'feature_fraction': 0.5634472554154152, 'bagging_fraction': 0.4765444595788658, 'bagging_freq': 4, 'max_cat_threshold': 30}. Best is trial 8 with value: 2.9660700030178018.
# [I 2025-01-30 13:46:44,109] Trial 10 finished with value: 4.182382108539913 and parameters: {'learning_rate': 0.013165933467547377, 'max_depth': 9, 'num_leaves': 6, 'min_child_samples': 43, 'lambda_l1': 12.48313497260903, 'lambda_l2': 67.52109642693719, 'feature_fraction': 0.5118399538955274, 'bagging_fraction': 0.2904759618315809, 'bagging_freq': 4, 'max_cat_threshold': 30}. Best is trial 8 with value: 2.9660700030178018.
# [I 2025-01-30 13:46:44,215] Trial 11 finished with value: 3.215345651474256 and parameters: {'learning_rate': 0.054437784296568155, 'max_depth': 8, 'num_leaves': 5, 'min_child_samples': 6, 'lambda_l1': 24.013950689427254, 'lambda_l2': 0.2080129079108275, 'feature_fraction': 0.8396317128362367, 'bagging_fraction': 0.1510597770084376, 'bagging_freq': 11, 'max_cat_threshold': 11}. Best is trial 8 with value: 2.9660700030178018.
# [I 2025-01-30 13:46:44,309] Trial 12 finished with value: 2.9427205285889557 and parameters: {'learning_rate': 0.09136212726190407, 'max_depth': 3, 'num_leaves': 9, 'min_child_samples': 5, 'lambda_l1': 21.751268183099256, 'lambda_l2': 4.157490211237569, 'feature_fraction': 0.7736130292696504, 'bagging_fraction': 0.9647681062217006, 'bagging_freq': 10, 'max_cat_threshold': 10}. Best is trial 12 with value: 2.9427205285889557.
# [I 2025-01-30 13:46:44,425] Trial 13 finished with value: 2.9788910808842517 and parameters: {'learning_rate': 0.09755068284909979, 'max_depth': 3, 'num_leaves': 9, 'min_child_samples': 37, 'lambda_l1': 18.971896467962328, 'lambda_l2': 46.59817195250509, 'feature_fraction': 0.7221323688780421, 'bagging_fraction': 0.9953343321470862, 'bagging_freq': 8, 'max_cat_threshold': 15}. Best is trial 12 with value: 2.9427205285889557.
# [I 2025-01-30 13:46:44,525] Trial 14 finished with value: 3.015102123189308 and parameters: {'learning_rate': 0.052842528849360505, 'max_depth': 4, 'num_leaves': 9, 'min_child_samples': 6, 'lambda_l1': 20.19774443888111, 'lambda_l2': 3.953440798506989, 'feature_fraction': 0.7529371182811764, 'bagging_fraction': 0.7560487591544227, 'bagging_freq': 11, 'max_cat_threshold': 13}. Best is trial 12 with value: 2.9427205285889557.
# [I 2025-01-30 13:46:44,625] Trial 15 finished with value: 3.055780694809263 and parameters: {'learning_rate': 0.053412746914921434, 'max_depth': 4, 'num_leaves': 9, 'min_child_samples': 5, 'lambda_l1': 33.35259218279509, 'lambda_l2': 2.5290341122771096, 'feature_fraction': 0.38787286635918194, 'bagging_fraction': 0.7762156571387607, 'bagging_freq': 11, 'max_cat_threshold': 10}. Best is trial 12 with value: 2.9427205285889557.
# [I 2025-01-30 13:46:44,725] Trial 16 finished with value: 3.058946785549963 and parameters: {'learning_rate': 0.05733115884555354, 'max_depth': 4, 'num_leaves': 9, 'min_child_samples': 19, 'lambda_l1': 36.65068719533119, 'lambda_l2': 12.648346656068991, 'feature_fraction': 0.4139294207945808, 'bagging_fraction': 0.7901149928307762, 'bagging_freq': 11, 'max_cat_threshold': 20}. Best is trial 12 with value: 2.9427205285889557.
# [I 2025-01-30 13:46:44,842] Trial 17 finished with value: 3.015317890403971 and parameters: {'learning_rate': 0.07134682922893286, 'max_depth': 5, 'num_leaves': 8, 'min_child_samples': 50, 'lambda_l1': 39.74820202952783, 'lambda_l2': 13.153603908325223, 'feature_fraction': 0.4471619212486387, 'bagging_fraction': 0.8168554294760095, 'bagging_freq': 6, 'max_cat_threshold': 19}. Best is trial 12 with value: 2.9427205285889557.
# [I 2025-01-30 13:46:44,942] Trial 18 finished with value: 2.9749076193755353 and parameters: {'learning_rate': 0.07257166438173851, 'max_depth': 5, 'num_leaves': 8, 'min_child_samples': 13, 'lambda_l1': 26.692971654705367, 'lambda_l2': 31.88429615298854, 'feature_fraction': 0.9063419687584431, 'bagging_fraction': 0.860204166029459, 'bagging_freq': 6, 'max_cat_threshold': 15}. Best is trial 12 with value: 2.9427205285889557.
# [I 2025-01-30 13:46:45,059] Trial 19 finished with value: 3.1464785964245805 and parameters: {'learning_rate': 0.041952464457157196, 'max_depth': 8, 'num_leaves': 8, 'min_child_samples': 14, 'lambda_l1': 28.224621384993114, 'lambda_l2': 32.165972458049595, 'feature_fraction': 0.8920485869391254, 'bagging_fraction': 0.6778949967078604, 'bagging_freq': 13, 'max_cat_threshold': 16}. Best is trial 12 with value: 2.9427205285889557.
# [I 2025-01-30 13:46:45,196] Trial 20 finished with value: 3.1530085244156125 and parameters: {'learning_rate': 0.03759732687124122, 'max_depth': 8, 'num_leaves': 9, 'min_child_samples': 21, 'lambda_l1': 14.097518052937998, 'lambda_l2': 24.06655974469378, 'feature_fraction': 0.8263794099002105, 'bagging_fraction': 0.6835835073667622, 'bagging_freq': 9, 'max_cat_threshold': 22}. Best is trial 12 with value: 2.9427205285889557.
# [I 2025-01-30 13:46:45,309] Trial 21 finished with value: 3.1447845213932886 and parameters: {'learning_rate': 0.0389070888638128, 'max_depth': 8, 'num_leaves': 9, 'min_child_samples': 22, 'lambda_l1': 15.289665089813889, 'lambda_l2': 24.251604764320927, 'feature_fraction': 0.9881632599513852, 'bagging_fraction': 0.9265567639649531, 'bagging_freq': 9, 'max_cat_threshold': 22}. Best is trial 12 with value: 2.9427205285889557.
# [I 2025-01-30 13:46:45,417] Trial 22 finished with value: 2.9681676179239074 and parameters: {'learning_rate': 0.07430902454077282, 'max_depth': 5, 'num_leaves': 8, 'min_child_samples': 11, 'lambda_l1': 25.351678992231413, 'lambda_l2': 29.416328987463118, 'feature_fraction': 0.6885315201568196, 'bagging_fraction': 0.9092564352300395, 'bagging_freq': 6, 'max_cat_threshold': 13}. Best is trial 12 with value: 2.9427205285889557.
# [I 2025-01-30 13:46:45,525] Trial 23 finished with value: 2.9574101858815567 and parameters: {'learning_rate': 0.0737606158274955, 'max_depth': 5, 'num_leaves': 8, 'min_child_samples': 10, 'lambda_l1': 25.43237865692371, 'lambda_l2': 35.2437329904883, 'feature_fraction': 0.6715105459425882, 'bagging_fraction': 0.9836680068555719, 'bagging_freq': 6, 'max_cat_threshold': 13}. Best is trial 12 with value: 2.9427205285889557.
# [I 2025-01-30 13:46:45,609] Trial 24 finished with value: 3.017140915529559 and parameters: {'learning_rate': 0.0687613052064862, 'max_depth': 5, 'num_leaves': 7, 'min_child_samples': 10, 'lambda_l1': 22.2866842341067, 'lambda_l2': 39.03880490107659, 'feature_fraction': 0.6659503275831856, 'bagging_fraction': 0.99911519670162, 'bagging_freq': 9, 'max_cat_threshold': 12}. Best is trial 12 with value: 2.9427205285889557.
# [I 2025-01-30 13:46:45,725] Trial 25 finished with value: 3.0473232334544393 and parameters: {'learning_rate': 0.061364622656408546, 'max_depth': 7, 'num_leaves': 7, 'min_child_samples': 9, 'lambda_l1': 20.17966353658984, 'lambda_l2': 37.35154408219717, 'feature_fraction': 0.6535072446320492, 'bagging_fraction': 0.9948493764387437, 'bagging_freq': 9, 'max_cat_threshold': 12}. Best is trial 12 with value: 2.9427205285889557.
# [I 2025-01-30 13:46:45,809] Trial 26 finished with value: 2.9820291152065304 and parameters: {'learning_rate': 0.09803566010441227, 'max_depth': 7, 'num_leaves': 6, 'min_child_samples': 32, 'lambda_l1': 40.4559956458163, 'lambda_l2': 36.95939653055979, 'feature_fraction': 0.7873225553087572, 'bagging_fraction': 0.8407846869821487, 'bagging_freq': 12, 'max_cat_threshold': 10}. Best is trial 12 with value: 2.9427205285889557.
# [I 2025-01-30 13:46:45,925] Trial 27 finished with value: 2.983451680776162 and parameters: {'learning_rate': 0.09941050987086116, 'max_depth': 3, 'num_leaves': 6, 'min_child_samples': 31, 'lambda_l1': 3.2282421133051606, 'lambda_l2': 47.28204773411821, 'feature_fraction': 0.792126295199576, 'bagging_fraction': 0.8462608003318617, 'bagging_freq': 13, 'max_cat_threshold': 17}. Best is trial 12 with value: 2.9427205285889557.
# [I 2025-01-30 13:46:46,009] Trial 28 finished with value: 3.1734038496696484 and parameters: {'learning_rate': 0.04647240764687792, 'max_depth': 3, 'num_leaves': 10, 'min_child_samples': 16, 'lambda_l1': 2.3168391578214553, 'lambda_l2': 49.18439208665159, 'feature_fraction': 0.5014272324342154, 'bagging_fraction': 0.7512728324117162, 'bagging_freq': 7, 'max_cat_threshold': 17}. Best is trial 12 with value: 2.9427205285889557.
# [I 2025-01-30 13:46:46,125] Trial 29 finished with value: 2.935439226934401 and parameters: {'learning_rate': 0.0760077989340361, 'max_depth': 5, 'num_leaves': 10, 'min_child_samples': 17, 'lambda_l1': 31.548197926031044, 'lambda_l2': 10.170539630698975, 'feature_fraction': 0.5015647817482277, 'bagging_fraction': 0.751858143539023, 'bagging_freq': 7, 'max_cat_threshold': 14}. Best is trial 29 with value: 2.935439226934401.
# [I 2025-01-30 13:46:46,225] Trial 30 finished with value: 3.0100263889115424 and parameters: {'learning_rate': 0.0812067864401978, 'max_depth': 5, 'num_leaves': 8, 'min_child_samples': 44, 'lambda_l1': 29.834825204364666, 'lambda_l2': 12.095650792028456, 'feature_fraction': 0.618720966149443, 'bagging_fraction': 0.5864170186606855, 'bagging_freq': 10, 'max_cat_threshold': 25}. Best is trial 29 with value: 2.935439226934401.
# [I 2025-01-30 13:46:46,342] Trial 31 finished with value: 3.0589905133631747 and parameters: {'learning_rate': 0.06300904771762303, 'max_depth': 4, 'num_leaves': 10, 'min_child_samples': 9, 'lambda_l1': 31.81502994899573, 'lambda_l2': 7.456784704667076, 'feature_fraction': 0.3086902829311574, 'bagging_fraction': 0.5741069970276098, 'bagging_freq': 7, 'max_cat_threshold': 14}. Best is trial 29 with value: 2.935439226934401.
# [I 2025-01-30 13:46:46,425] Trial 32 finished with value: 2.989676945377065 and parameters: {'learning_rate': 0.06554525469964452, 'max_depth': 4, 'num_leaves': 10, 'min_child_samples': 9, 'lambda_l1': 36.53470050841581, 'lambda_l2': 5.607583123227563, 'feature_fraction': 0.5019190554584698, 'bagging_fraction': 0.9313204824775825, 'bagging_freq': 7, 'max_cat_threshold': 14}. Best is trial 29 with value: 2.935439226934401.
# [I 2025-01-30 13:46:46,542] Trial 33 finished with value: 2.9338820143993716 and parameters: {'learning_rate': 0.0828709849514069, 'max_depth': 6, 'num_leaves': 9, 'min_child_samples': 14, 'lambda_l1': 37.528938612065275, 'lambda_l2': 17.35673914945245, 'feature_fraction': 0.5357664351100334, 'bagging_fraction': 0.9290852541149912, 'bagging_freq': 10, 'max_cat_threshold': 10}. Best is trial 33 with value: 2.9338820143993716.
# [I 2025-01-30 13:46:46,642] Trial 34 finished with value: 2.9198275472530524 and parameters: {'learning_rate': 0.08223549460460548, 'max_depth': 6, 'num_leaves': 9, 'min_child_samples': 13, 'lambda_l1': 10.109372871350155, 'lambda_l2': 19.309863124341035, 'feature_fraction': 0.6042338467253942, 'bagging_fraction': 0.728238189679025, 'bagging_freq': 5, 'max_cat_threshold': 10}. Best is trial 34 with value: 2.9198275472530524.
# [I 2025-01-30 13:46:46,775] Trial 35 finished with value: 2.9785688968955806 and parameters: {'learning_rate': 0.08162416071530187, 'max_depth': 5, 'num_leaves': 9, 'min_child_samples': 14, 'lambda_l1': 49.68498705100393, 'lambda_l2': 17.38977085917611, 'feature_fraction': 0.36445894212032526, 'bagging_fraction': 0.7208959193949871, 'bagging_freq': 5, 'max_cat_threshold': 11}. Best is trial 34 with value: 2.9198275472530524.
# [I 2025-01-30 13:46:46,859] Trial 36 finished with value: 3.052426901785716 and parameters: {'learning_rate': 0.08242542063759725, 'max_depth': 6, 'num_leaves': 9, 'min_child_samples': 16, 'lambda_l1': 47.309535502255095, 'lambda_l2': 20.477200331502353, 'feature_fraction': 0.32065185563277443, 'bagging_fraction': 0.6324005529013932, 'bagging_freq': 5, 'max_cat_threshold': 10}. Best is trial 34 with value: 2.9198275472530524.
# [I 2025-01-30 13:46:46,987] Trial 37 finished with value: 3.0479115882660412 and parameters: {'learning_rate': 0.04829172080108154, 'max_depth': 6, 'num_leaves': 10, 'min_child_samples': 17, 'lambda_l1': 10.581823273245245, 'lambda_l2': 18.438197646640635, 'feature_fraction': 0.4787085036774795, 'bagging_fraction': 0.6088788970020544, 'bagging_freq': 2, 'max_cat_threshold': 10}. Best is trial 34 with value: 2.9198275472530524.
# [I 2025-01-30 13:46:47,080] Trial 38 finished with value: 3.4774600918291263 and parameters: {'learning_rate': 0.018364178031090826, 'max_depth': 7, 'num_leaves': 10, 'min_child_samples': 25, 'lambda_l1': 10.433948807904578, 'lambda_l2': 9.525541487385713, 'feature_fraction': 0.4612752542123364, 'bagging_fraction': 0.7070158016789858, 'bagging_freq': 1, 'max_cat_threshold': 11}. Best is trial 34 with value: 2.9198275472530524.
# [I 2025-01-30 13:46:47,173] Trial 39 finished with value: 2.9473527924115195 and parameters: {'learning_rate': 0.09112989999265592, 'max_depth': 7, 'num_leaves': 10, 'min_child_samples': 24, 'lambda_l1': 7.775034934330172, 'lambda_l2': 9.23918589861658, 'feature_fraction': 0.22387753156076012, 'bagging_fraction': 0.5279985338164266, 'bagging_freq': 1, 'max_cat_threshold': 11}. Best is trial 34 with value: 2.9198275472530524.
# [I 2025-01-30 13:46:47,272] Trial 40 finished with value: 3.0135893752992784 and parameters: {'learning_rate': 0.08734288713049385, 'max_depth': 7, 'num_leaves': 9, 'min_child_samples': 24, 'lambda_l1': 40.15212927829429, 'lambda_l2': 13.99599220952641, 'feature_fraction': 0.23746731300980428, 'bagging_fraction': 0.8915856066277796, 'bagging_freq': 10, 'max_cat_threshold': 12}. Best is trial 34 with value: 2.9198275472530524.
# [I 2025-01-30 13:46:47,390] Trial 41 finished with value: 2.939381715032644 and parameters: {'learning_rate': 0.08522330661021378, 'max_depth': 6, 'num_leaves': 9, 'min_child_samples': 20, 'lambda_l1': 39.44903359277715, 'lambda_l2': 15.682335261764706, 'feature_fraction': 0.619678751648401, 'bagging_fraction': 0.8882158240109591, 'bagging_freq': 10, 'max_cat_threshold': 12}. Best is trial 34 with value: 2.9198275472530524.
# [I 2025-01-30 13:46:47,474] Trial 42 finished with value: 3.2360911765064095 and parameters: {'learning_rate': 0.09117659331345566, 'max_depth': 6, 'num_leaves': 10, 'min_child_samples': 28, 'lambda_l1': 6.599485221271545, 'lambda_l2': 7.79810951829494, 'feature_fraction': 0.10256286337016829, 'bagging_fraction': 0.5230087580741513, 'bagging_freq': 3, 'max_cat_threshold': 12}. Best is trial 34 with value: 2.9198275472530524.
# [I 2025-01-30 13:46:47,604] Trial 43 finished with value: 2.953904171728899 and parameters: {'learning_rate': 0.07777320246546589, 'max_depth': 6, 'num_leaves': 9, 'min_child_samples': 21, 'lambda_l1': 43.781798853403735, 'lambda_l2': 15.586298991077205, 'feature_fraction': 0.6044811066286915, 'bagging_fraction': 0.8073095955580526, 'bagging_freq': 10, 'max_cat_threshold': 14}. Best is trial 34 with value: 2.9198275472530524.
# [I 2025-01-30 13:46:47,690] Trial 44 finished with value: 3.0121555515705327 and parameters: {'learning_rate': 0.07665214374575526, 'max_depth': 6, 'num_leaves': 9, 'min_child_samples': 20, 'lambda_l1': 53.1689968218813, 'lambda_l2': 27.85803059775472, 'feature_fraction': 0.5519666176323139, 'bagging_fraction': 0.8063759719996073, 'bagging_freq': 10, 'max_cat_threshold': 14}. Best is trial 34 with value: 2.9198275472530524.
# [I 2025-01-30 13:46:47,825] Trial 45 finished with value: 3.2522827332360302 and parameters: {'learning_rate': 0.030517477655071016, 'max_depth': 6, 'num_leaves': 9, 'min_child_samples': 19, 'lambda_l1': 34.449838502392446, 'lambda_l2': 22.29664983163677, 'feature_fraction': 0.5354680960102443, 'bagging_fraction': 0.8864223313077091, 'bagging_freq': 12, 'max_cat_threshold': 10}. Best is trial 34 with value: 2.9198275472530524.
# [I 2025-01-30 13:46:47,907] Trial 46 finished with value: 3.309195970709046 and parameters: {'learning_rate': 0.02677378528975579, 'max_depth': 6, 'num_leaves': 9, 'min_child_samples': 12, 'lambda_l1': 17.486535844133336, 'lambda_l2': 22.58399863991984, 'feature_fraction': 0.5346412971704129, 'bagging_fraction': 0.882228030117253, 'bagging_freq': 12, 'max_cat_threshold': 10}. Best is trial 34 with value: 2.9198275472530524.
# [I 2025-01-30 13:46:48,021] Trial 47 finished with value: 3.640803503997609 and parameters: {'learning_rate': 0.017322259661564584, 'max_depth': 5, 'num_leaves': 10, 'min_child_samples': 12, 'lambda_l1': 69.12372434701174, 'lambda_l2': 1.7847479580481083, 'feature_fraction': 0.6179215539070383, 'bagging_fraction': 0.37184717346395385, 'bagging_freq': 7, 'max_cat_threshold': 12}. Best is trial 34 with value: 2.9198275472530524.
# [I 2025-01-30 13:46:48,139] Trial 48 finished with value: 3.0118667218315784 and parameters: {'learning_rate': 0.05971934008453495, 'max_depth': 9, 'num_leaves': 10, 'min_child_samples': 7, 'lambda_l1': 63.904436353873294, 'lambda_l2': 0.6913418540311937, 'feature_fraction': 0.7255401698585273, 'bagging_fraction': 0.9470046700310456, 'bagging_freq': 8, 'max_cat_threshold': 12}. Best is trial 34 with value: 2.9198275472530524.
# [I 2025-01-30 13:46:48,264] Trial 49 finished with value: 2.9898521565072924 and parameters: {'learning_rate': 0.06347354324760923, 'max_depth': 9, 'num_leaves': 10, 'min_child_samples': 17, 'lambda_l1': 29.70013381922454, 'lambda_l2': 27.28546728520019, 'feature_fraction': 0.7441472516007621, 'bagging_fraction': 0.9576637962338391, 'bagging_freq': 8, 'max_cat_threshold': 18}. Best is trial 34 with value: 2.9198275472530524.
# [I 2025-01-30 13:46:48,309] Trial 50 finished with value: 3.0211526661288834 and parameters: {'learning_rate': 0.09010541064804825, 'max_depth': 3, 'num_leaves': 9, 'min_child_samples': 16, 'lambda_l1': 43.83940322827985, 'lambda_l2': 27.254243993845858, 'feature_fraction': 0.5831452642082352, 'bagging_fraction': 0.7397379733583644, 'bagging_freq': 8, 'max_cat_threshold': 18}. Best is trial 34 with value: 2.9198275472530524.
# [I 2025-01-30 13:46:48,484] Trial 51 finished with value: 3.0665936106939835 and parameters: {'learning_rate': 0.08908918637809483, 'max_depth': 3, 'num_leaves': 5, 'min_child_samples': 28, 'lambda_l1': 43.080244031626144, 'lambda_l2': 16.12781668560622, 'feature_fraction': 0.5816399504620731, 'bagging_fraction': 0.7643943190097751, 'bagging_freq': 15, 'max_cat_threshold': 15}. Best is trial 34 with value: 2.9198275472530524.
# [I 2025-01-30 13:46:48,532] Trial 52 finished with value: 3.081779089922572 and parameters: {'learning_rate': 0.09089572494731833, 'max_depth': 7, 'num_leaves': 5, 'min_child_samples': 23, 'lambda_l1': 8.378261082440325, 'lambda_l2': 9.819205453764246, 'feature_fraction': 0.21883098065212173, 'bagging_fraction': 0.454374633754714, 'bagging_freq': 1, 'max_cat_threshold': 11}. Best is trial 34 with value: 2.9198275472530524.
# [I 2025-01-30 13:46:48,712] Trial 53 finished with value: 3.006256096812085 and parameters: {'learning_rate': 0.06776250408062813, 'max_depth': 7, 'num_leaves': 10, 'min_child_samples': 23, 'lambda_l1': 0.18988193499703243, 'lambda_l2': 10.09936633103742, 'feature_fraction': 0.20890035834188084, 'bagging_fraction': 0.49187458414713703, 'bagging_freq': 1, 'max_cat_threshold': 11}. Best is trial 34 with value: 2.9198275472530524.
# [I 2025-01-30 13:46:48,775] Trial 54 finished with value: 2.954245838244815 and parameters: {'learning_rate': 0.07084168175689325, 'max_depth': 7, 'num_leaves': 10, 'min_child_samples': 7, 'lambda_l1': 0.2132247907913749, 'lambda_l2': 5.553480198295924, 'feature_fraction': 0.42402314088934834, 'bagging_fraction': 0.5034578619223691, 'bagging_freq': 3, 'max_cat_threshold': 11}. Best is trial 34 with value: 2.9198275472530524.
# [I 2025-01-30 13:46:49,011] Trial 56 finished with value: 2.8883874313171294 and parameters: {'learning_rate': 0.0998195858652152, 'max_depth': 6, 'num_leaves': 9, 'min_child_samples': 19, 'lambda_l1': 17.548243077158507, 'lambda_l2': 11.113991992927168, 'feature_fraction': 0.35689640015046137, 'bagging_fraction': 0.644641966389382, 'bagging_freq': 5, 'max_cat_threshold': 13}. Best is trial 56 with value: 2.8883874313171294.
# [I 2025-01-30 13:46:49,025] Trial 55 finished with value: 2.8832324426662965 and parameters: {'learning_rate': 0.09830739421745427, 'max_depth': 7, 'num_leaves': 9, 'min_child_samples': 26, 'lambda_l1': 15.567144048456012, 'lambda_l2': 4.565393448756675, 'feature_fraction': 0.7015012327915676, 'bagging_fraction': 0.6314174223831669, 'bagging_freq': 5, 'max_cat_threshold': 13}. Best is trial 55 with value: 2.8832324426662965.
# [I 2025-01-30 13:46:49,275] Trial 57 finished with value: 2.969319990530815 and parameters: {'learning_rate': 0.09805771953422729, 'max_depth': 6, 'num_leaves': 8, 'min_child_samples': 15, 'lambda_l1': 37.81777941989134, 'lambda_l2': 20.255506701510505, 'feature_fraction': 0.38541261965465284, 'bagging_fraction': 0.6624720384201883, 'bagging_freq': 5, 'max_cat_threshold': 13}. Best is trial 55 with value: 2.8832324426662965.
# [I 2025-01-30 13:46:49,275] Trial 58 finished with value: 2.9809049587321037 and parameters: {'learning_rate': 0.09965890621811554, 'max_depth': 6, 'num_leaves': 8, 'min_child_samples': 35, 'lambda_l1': 14.849543246026958, 'lambda_l2': 14.356044940678963, 'feature_fraction': 0.374043029118175, 'bagging_fraction': 0.6602976463401797, 'bagging_freq': 5, 'max_cat_threshold': 13}. Best is trial 55 with value: 2.8832324426662965.
# [I 2025-01-30 13:46:49,494] Trial 59 finished with value: 2.9087312125103817 and parameters: {'learning_rate': 0.08213219355759159, 'max_depth': 5, 'num_leaves': 9, 'min_child_samples': 18, 'lambda_l1': 12.311664768779725, 'lambda_l2': 11.66661587134226, 'feature_fraction': 0.6273867213191241, 'bagging_fraction': 0.6279566438072269, 'bagging_freq': 4, 'max_cat_threshold': 16}. Best is trial 55 with value: 2.8832324426662965.
# [I 2025-01-30 13:46:49,509] Trial 60 finished with value: 2.899565703960501 and parameters: {'learning_rate': 0.08279959295652016, 'max_depth': 5, 'num_leaves': 9, 'min_child_samples': 18, 'lambda_l1': 22.90833701054794, 'lambda_l2': 3.562852015697511, 'feature_fraction': 0.6213086323625829, 'bagging_fraction': 0.6352783700716326, 'bagging_freq': 4, 'max_cat_threshold': 16}. Best is trial 55 with value: 2.8832324426662965.
# [I 2025-01-30 13:46:49,773] Trial 62 finished with value: 2.889646304128295 and parameters: {'learning_rate': 0.07791624069874205, 'max_depth': 5, 'num_leaves': 9, 'min_child_samples': 18, 'lambda_l1': 17.015733681223864, 'lambda_l2': 5.5771382366188735, 'feature_fraction': 0.6991927005048894, 'bagging_fraction': 0.6229269342391195, 'bagging_freq': 4, 'max_cat_threshold': 16}. Best is trial 55 with value: 2.8832324426662965.
# [I 2025-01-30 13:46:49,775] Trial 61 finished with value: 2.9219221238937263 and parameters: {'learning_rate': 0.0761052304682884, 'max_depth': 5, 'num_leaves': 9, 'min_child_samples': 18, 'lambda_l1': 17.489182569689838, 'lambda_l2': 5.282840940195506, 'feature_fraction': 0.688425708493791, 'bagging_fraction': 0.7054353751757769, 'bagging_freq': 4, 'max_cat_threshold': 16}. Best is trial 55 with value: 2.8832324426662965.
# [I 2025-01-30 13:46:49,980] Trial 64 finished with value: 2.9666133189143773 and parameters: {'learning_rate': 0.05630439036436201, 'max_depth': 4, 'num_leaves': 9, 'min_child_samples': 27, 'lambda_l1': 17.270374586611748, 'lambda_l2': 3.8905085095736296, 'feature_fraction': 0.6966762305891574, 'bagging_fraction': 0.6405037155030677, 'bagging_freq': 4, 'max_cat_threshold': 16}. Best is trial 55 with value: 2.8832324426662965.
# [I 2025-01-30 13:46:49,995] Trial 63 finished with value: 2.9608238604213413 and parameters: {'learning_rate': 0.05645098741169784, 'max_depth': 4, 'num_leaves': 9, 'min_child_samples': 27, 'lambda_l1': 17.209128155053357, 'lambda_l2': 4.239460109435267, 'feature_fraction': 0.6765667623772449, 'bagging_fraction': 0.6121900459919027, 'bagging_freq': 4, 'max_cat_threshold': 16}. Best is trial 55 with value: 2.8832324426662965.
# [I 2025-01-30 13:46:50,232] Trial 65 finished with value: 2.945827800395813 and parameters: {'learning_rate': 0.07882779377656061, 'max_depth': 5, 'num_leaves': 8, 'min_child_samples': 18, 'lambda_l1': 12.73201034413357, 'lambda_l2': 7.275289584701433, 'feature_fraction': 0.6398605232276199, 'bagging_fraction': 0.5620300229822514, 'bagging_freq': 2, 'max_cat_threshold': 19}. Best is trial 55 with value: 2.8832324426662965.
# [I 2025-01-30 13:46:50,233] Trial 66 finished with value: 2.9292319446567965 and parameters: {'learning_rate': 0.07866368826049172, 'max_depth': 5, 'num_leaves': 8, 'min_child_samples': 18, 'lambda_l1': 12.804505109891778, 'lambda_l2': 7.538580568375673, 'feature_fraction': 0.7182693307965398, 'bagging_fraction': 0.5671503617445587, 'bagging_freq': 2, 'max_cat_threshold': 20}. Best is trial 55 with value: 2.8832324426662965.
# [I 2025-01-30 13:46:50,492] Trial 68 finished with value: 2.9246637283991457 and parameters: {'learning_rate': 0.06860367468002722, 'max_depth': 5, 'num_leaves': 9, 'min_child_samples': 21, 'lambda_l1': 22.583627331742946, 'lambda_l2': 0.23115995176708992, 'feature_fraction': 0.6424665286236187, 'bagging_fraction': 0.695982602121235, 'bagging_freq': 3, 'max_cat_threshold': 15}. Best is trial 55 with value: 2.8832324426662965.
# [I 2025-01-30 13:46:50,512] Trial 67 finished with value: 2.9207940292539947 and parameters: {'learning_rate': 0.07072613944360084, 'max_depth': 5, 'num_leaves': 9, 'min_child_samples': 21, 'lambda_l1': 22.717524967263213, 'lambda_l2': 11.702324741167578, 'feature_fraction': 0.8635883203248431, 'bagging_fraction': 0.6985973814966883, 'bagging_freq': 3, 'max_cat_threshold': 15}. Best is trial 55 with value: 2.8832324426662965.
# [I 2025-01-30 13:46:50,716] Trial 70 finished with value: 3.2802352002037636 and parameters: {'learning_rate': 0.048283273446873845, 'max_depth': 4, 'num_leaves': 9, 'min_child_samples': 22, 'lambda_l1': 10.478398311417907, 'lambda_l2': 12.23512919023272, 'feature_fraction': 0.8623184220694952, 'bagging_fraction': 0.12139604122727798, 'bagging_freq': 4, 'max_cat_threshold': 18}. Best is trial 55 with value: 2.8832324426662965.
# [I 2025-01-30 13:46:50,775] Trial 69 finished with value: 2.9617467131673063 and parameters: {'learning_rate': 0.049949580838526096, 'max_depth': 5, 'num_leaves': 9, 'min_child_samples': 30, 'lambda_l1': 4.472242089091556, 'lambda_l2': 2.9328208402893026, 'feature_fraction': 0.6987250575640129, 'bagging_fraction': 0.6102804241702714, 'bagging_freq': 4, 'max_cat_threshold': 18}. Best is trial 55 with value: 2.8832324426662965.
# [I 2025-01-30 13:46:50,971] Trial 71 finished with value: 3.8007407458118 and parameters: {'learning_rate': 0.010745813100259882, 'max_depth': 5, 'num_leaves': 9, 'min_child_samples': 30, 'lambda_l1': 20.591877999690006, 'lambda_l2': 11.732246349708483, 'feature_fraction': 0.9654558264982362, 'bagging_fraction': 0.6187422113451981, 'bagging_freq': 3, 'max_cat_threshold': 17}. Best is trial 55 with value: 2.8832324426662965.
# [I 2025-01-30 13:46:51,031] Trial 72 finished with value: 3.0062521621400706 and parameters: {'learning_rate': 0.07220282162250917, 'max_depth': 5, 'num_leaves': 9, 'min_child_samples': 19, 'lambda_l1': 19.901458369075506, 'lambda_l2': 65.2208877552665, 'feature_fraction': 0.8051821546639883, 'bagging_fraction': 0.7284128210498808, 'bagging_freq': 3, 'max_cat_threshold': 16}. Best is trial 55 with value: 2.8832324426662965.
# [I 2025-01-30 13:46:51,230] Trial 73 finished with value: 2.9416906954934863 and parameters: {'learning_rate': 0.0728186137116224, 'max_depth': 5, 'num_leaves': 9, 'min_child_samples': 19, 'lambda_l1': 18.005325869403745, 'lambda_l2': 6.387429803422519, 'feature_fraction': 0.8384035175958349, 'bagging_fraction': 0.7253303853355898, 'bagging_freq': 5, 'max_cat_threshold': 16}. Best is trial 55 with value: 2.8832324426662965.
# [I 2025-01-30 13:46:51,307] Trial 74 finished with value: 2.9336023426543285 and parameters: {'learning_rate': 0.09542717020486921, 'max_depth': 5, 'num_leaves': 9, 'min_child_samples': 13, 'lambda_l1': 23.47766050724111, 'lambda_l2': 5.745703615641135, 'feature_fraction': 0.7656435364734137, 'bagging_fraction': 0.6574531716461512, 'bagging_freq': 6, 'max_cat_threshold': 15}. Best is trial 55 with value: 2.8832324426662965.
# [I 2025-01-30 13:46:51,473] Trial 75 finished with value: 2.9026484474146876 and parameters: {'learning_rate': 0.08547010085788369, 'max_depth': 4, 'num_leaves': 9, 'min_child_samples': 15, 'lambda_l1': 15.211649767237061, 'lambda_l2': 4.818490032197456, 'feature_fraction': 0.7611675467905268, 'bagging_fraction': 0.6713615611835451, 'bagging_freq': 6, 'max_cat_threshold': 15}. Best is trial 55 with value: 2.8832324426662965.
# [I 2025-01-30 13:46:51,548] Trial 76 finished with value: 2.928020330458963 and parameters: {'learning_rate': 0.08267095007954561, 'max_depth': 8, 'num_leaves': 8, 'min_child_samples': 15, 'lambda_l1': 27.239085218193622, 'lambda_l2': 2.586689187935397, 'feature_fraction': 0.9457823042973206, 'bagging_fraction': 0.6884229281720124, 'bagging_freq': 4, 'max_cat_threshold': 15}. Best is trial 55 with value: 2.8832324426662965.
# [I 2025-01-30 13:46:51,702] Trial 77 finished with value: 2.929828765752096 and parameters: {'learning_rate': 0.0841878045330883, 'max_depth': 4, 'num_leaves': 8, 'min_child_samples': 15, 'lambda_l1': 13.339730986519644, 'lambda_l2': 2.354339858448791, 'feature_fraction': 0.893349603142169, 'bagging_fraction': 0.5917661580797329, 'bagging_freq': 5, 'max_cat_threshold': 15}. Best is trial 55 with value: 2.8832324426662965.
# [I 2025-01-30 13:46:51,775] Trial 78 finished with value: 2.919234664567689 and parameters: {'learning_rate': 0.08662208672880102, 'max_depth': 4, 'num_leaves': 9, 'min_child_samples': 25, 'lambda_l1': 9.143897590469273, 'lambda_l2': 11.29167584274538, 'feature_fraction': 0.8701584321337237, 'bagging_fraction': 0.5952534251786097, 'bagging_freq': 6, 'max_cat_threshold': 27}. Best is trial 55 with value: 2.8832324426662965.
# [I 2025-01-30 13:46:51,944] Trial 79 finished with value: 2.8722756164462204 and parameters: {'learning_rate': 0.0877129775531665, 'max_depth': 4, 'num_leaves': 9, 'min_child_samples': 25, 'lambda_l1': 9.068376054047476, 'lambda_l2': 8.489563145517554, 'feature_fraction': 0.813025972395311, 'bagging_fraction': 0.6411120900744535, 'bagging_freq': 6, 'max_cat_threshold': 28}. Best is trial 79 with value: 2.8722756164462204.
# [I 2025-01-30 13:46:52,008] Trial 80 finished with value: 2.9255478595931983 and parameters: {'learning_rate': 0.09330722361035815, 'max_depth': 4, 'num_leaves': 9, 'min_child_samples': 13, 'lambda_l1': 5.046609849936398, 'lambda_l2': 7.902647136698832, 'feature_fraction': 0.7494459843187196, 'bagging_fraction': 0.54779323999103, 'bagging_freq': 6, 'max_cat_threshold': 26}. Best is trial 79 with value: 2.8722756164462204.
# [I 2025-01-30 13:46:52,186] Trial 81 finished with value: 2.968405263586629 and parameters: {'learning_rate': 0.09442353701264133, 'max_depth': 4, 'num_leaves': 9, 'min_child_samples': 25, 'lambda_l1': 15.985457688243681, 'lambda_l2': 9.040365768884003, 'feature_fraction': 0.7367855113274272, 'bagging_fraction': 0.5453196459776924, 'bagging_freq': 6, 'max_cat_threshold': 28}. Best is trial 79 with value: 2.8722756164462204.
# [I 2025-01-30 13:46:52,258] Trial 82 finished with value: 2.9151831638861014 and parameters: {'learning_rate': 0.08502635702293579, 'max_depth': 4, 'num_leaves': 9, 'min_child_samples': 25, 'lambda_l1': 9.389757301413521, 'lambda_l2': 8.560883444647065, 'feature_fraction': 0.8022038527564891, 'bagging_fraction': 0.6411745890903706, 'bagging_freq': 6, 'max_cat_threshold': 28}. Best is trial 79 with value: 2.8722756164462204.
# [I 2025-01-30 13:46:52,454] Trial 83 finished with value: 2.9192492797203102 and parameters: {'learning_rate': 0.08648148434384195, 'max_depth': 4, 'num_leaves': 9, 'min_child_samples': 25, 'lambda_l1': 10.393933413554265, 'lambda_l2': 14.091425597730868, 'feature_fraction': 0.8012245171506142, 'bagging_fraction': 0.6520114756175084, 'bagging_freq': 5, 'max_cat_threshold': 29}. Best is trial 79 with value: 2.8722756164462204.
# [I 2025-01-30 13:46:52,525] Trial 84 finished with value: 2.9397083083836586 and parameters: {'learning_rate': 0.08735814726016747, 'max_depth': 4, 'num_leaves': 9, 'min_child_samples': 26, 'lambda_l1': 9.466367557144975, 'lambda_l2': 11.295568190356189, 'feature_fraction': 0.8121953592331624, 'bagging_fraction': 0.6364805170155345, 'bagging_freq': 6, 'max_cat_threshold': 29}. Best is trial 79 with value: 2.8722756164462204.
# [I 2025-01-30 13:46:52,660] Trial 85 finished with value: 3.0825875482866847 and parameters: {'learning_rate': 0.06583542617296266, 'max_depth': 3, 'num_leaves': 9, 'min_child_samples': 29, 'lambda_l1': 8.195191395054234, 'lambda_l2': 53.406713234690315, 'feature_fraction': 0.8195083387718937, 'bagging_fraction': 0.5909558938241064, 'bagging_freq': 6, 'max_cat_threshold': 27}. Best is trial 79 with value: 2.8722756164462204.
# [I 2025-01-30 13:46:52,758] Trial 86 finished with value: 2.961919459030741 and parameters: {'learning_rate': 0.064659072732578, 'max_depth': 4, 'num_leaves': 9, 'min_child_samples': 29, 'lambda_l1': 5.676003337721793, 'lambda_l2': 4.543149001499872, 'feature_fraction': 0.7674739430779259, 'bagging_fraction': 0.59064424061605, 'bagging_freq': 6, 'max_cat_threshold': 27}. Best is trial 79 with value: 2.8722756164462204.
# [I 2025-01-30 13:46:52,904] Trial 87 finished with value: 3.638609757190747 and parameters: {'learning_rate': 0.012781542134229548, 'max_depth': 4, 'num_leaves': 9, 'min_child_samples': 23, 'lambda_l1': 15.570241926420097, 'lambda_l2': 4.415660992793844, 'feature_fraction': 0.9261671172504027, 'bagging_fraction': 0.6676024988172006, 'bagging_freq': 5, 'max_cat_threshold': 24}. Best is trial 79 with value: 2.8722756164462204.
# [I 2025-01-30 13:46:52,994] Trial 88 finished with value: 2.8611023989967053 and parameters: {'learning_rate': 0.0990993766762265, 'max_depth': 4, 'num_leaves': 9, 'min_child_samples': 23, 'lambda_l1': 15.294671575416341, 'lambda_l2': 8.317286263522838, 'feature_fraction': 0.8644756790357606, 'bagging_fraction': 0.6757592368181801, 'bagging_freq': 5, 'max_cat_threshold': 31}. Best is trial 88 with value: 2.8611023989967053.
# [I 2025-01-30 13:46:53,121] Trial 89 finished with value: 2.9097046823487336 and parameters: {'learning_rate': 0.09998849951555414, 'max_depth': 4, 'num_leaves': 8, 'min_child_samples': 33, 'lambda_l1': 12.188068278424014, 'lambda_l2': 8.43319776746463, 'feature_fraction': 0.872281681440233, 'bagging_fraction': 0.6296347258172308, 'bagging_freq': 7, 'max_cat_threshold': 30}. Best is trial 88 with value: 2.8611023989967053.
# [I 2025-01-30 13:46:53,175] Trial 90 finished with value: 2.9242757515020465 and parameters: {'learning_rate': 0.09916661225113425, 'max_depth': 3, 'num_leaves': 8, 'min_child_samples': 20, 'lambda_l1': 14.270302591271388, 'lambda_l2': 8.712758286191983, 'feature_fraction': 0.7125410283822973, 'bagging_fraction': 0.626619628894233, 'bagging_freq': 5, 'max_cat_threshold': 32}. Best is trial 88 with value: 2.8611023989967053.
# [I 2025-01-30 13:46:53,347] Trial 91 finished with value: 2.96465579130783 and parameters: {'learning_rate': 0.09962864071732853, 'max_depth': 4, 'num_leaves': 7, 'min_child_samples': 35, 'lambda_l1': 11.958071665418533, 'lambda_l2': 1.024802440535057, 'feature_fraction': 0.8418778209798858, 'bagging_fraction': 0.6821791102830024, 'bagging_freq': 7, 'max_cat_threshold': 31}. Best is trial 88 with value: 2.8611023989967053.
# [I 2025-01-30 13:46:53,425] Trial 92 finished with value: 2.9435929348350562 and parameters: {'learning_rate': 0.09198389198118954, 'max_depth': 4, 'num_leaves': 9, 'min_child_samples': 35, 'lambda_l1': 11.372779238949075, 'lambda_l2': 7.19642185000461, 'feature_fraction': 0.8439445403590433, 'bagging_fraction': 0.6766998348579104, 'bagging_freq': 7, 'max_cat_threshold': 31}. Best is trial 88 with value: 2.8611023989967053.
# [I 2025-01-30 13:46:53,580] Trial 93 finished with value: 2.9423082309331656 and parameters: {'learning_rate': 0.09379470816307993, 'max_depth': 3, 'num_leaves': 9, 'min_child_samples': 33, 'lambda_l1': 11.759742003670752, 'lambda_l2': 6.748233660582143, 'feature_fraction': 0.7829871407218126, 'bagging_fraction': 0.6429296996248692, 'bagging_freq': 7, 'max_cat_threshold': 31}. Best is trial 88 with value: 2.8611023989967053.
# [I 2025-01-30 13:46:53,664] Trial 94 finished with value: 2.9746032716374198 and parameters: {'learning_rate': 0.0791778928461278, 'max_depth': 3, 'num_leaves': 8, 'min_child_samples': 22, 'lambda_l1': 19.48236047659376, 'lambda_l2': 6.250189398349196, 'feature_fraction': 0.7683053245165115, 'bagging_fraction': 0.6458727566845612, 'bagging_freq': 4, 'max_cat_threshold': 30}. Best is trial 88 with value: 2.8611023989967053.
# [I 2025-01-30 13:46:53,840] Trial 95 finished with value: 2.926757486389876 and parameters: {'learning_rate': 0.07997529431456583, 'max_depth': 4, 'num_leaves': 8, 'min_child_samples': 40, 'lambda_l1': 19.045651220439346, 'lambda_l2': 2.905457686207911, 'feature_fraction': 0.9026217532319165, 'bagging_fraction': 0.5748781265345483, 'bagging_freq': 4, 'max_cat_threshold': 30}. Best is trial 88 with value: 2.8611023989967053.
# [I 2025-01-30 13:46:53,942] Trial 96 finished with value: 3.357414861159506 and parameters: {'learning_rate': 0.020924521728902766, 'max_depth': 4, 'num_leaves': 9, 'min_child_samples': 39, 'lambda_l1': 16.163819777694997, 'lambda_l2': 2.5257449688876665, 'feature_fraction': 0.9009262693878746, 'bagging_fraction': 0.5683741912973427, 'bagging_freq': 5, 'max_cat_threshold': 29}. Best is trial 88 with value: 2.8611023989967053.
# [I 2025-01-30 13:46:54,068] Trial 97 finished with value: 2.9769852178505816 and parameters: {'learning_rate': 0.08555216771920948, 'max_depth': 4, 'num_leaves': 9, 'min_child_samples': 26, 'lambda_l1': 16.159398016659974, 'lambda_l2': 10.28690605534127, 'feature_fraction': 0.2732255165631816, 'bagging_fraction': 0.6151599192625749, 'bagging_freq': 5, 'max_cat_threshold': 29}. Best is trial 88 with value: 2.8611023989967053.
# [I 2025-01-30 13:46:54,168] Trial 98 finished with value: 2.8835520542906337 and parameters: {'learning_rate': 0.08707533817806037, 'max_depth': 4, 'num_leaves': 9, 'min_child_samples': 24, 'lambda_l1': 21.26429928198211, 'lambda_l2': 10.471444980798225, 'feature_fraction': 0.657237718014223, 'bagging_fraction': 0.6263561368573661, 'bagging_freq': 5, 'max_cat_threshold': 14}. Best is trial 88 with value: 2.8611023989967053.
# [I 2025-01-30 13:46:54,276] Trial 99 finished with value: 3.0557894304777444 and parameters: {'learning_rate': 0.07532355059697943, 'max_depth': 5, 'num_leaves': 7, 'min_child_samples': 24, 'lambda_l1': 21.351153300339472, 'lambda_l2': 13.467502820617034, 'feature_fraction': 0.6549147351755967, 'bagging_fraction': 0.23241869152732342, 'bagging_freq': 6, 'max_cat_threshold': 23}. Best is trial 88 with value: 2.8611023989967053.
# [I 2025-01-30 13:46:54,413] Trial 100 finished with value: 2.9442506594463698 and parameters: {'learning_rate': 0.09462406991948695, 'max_depth': 5, 'num_leaves': 9, 'min_child_samples': 24, 'lambda_l1': 24.965263308441298, 'lambda_l2': 13.187189153012177, 'feature_fraction': 0.6548113958964662, 'bagging_fraction': 0.5171201709835662, 'bagging_freq': 4, 'max_cat_threshold': 14}. Best is trial 88 with value: 2.8611023989967053.
# [I 2025-01-30 13:46:54,526] Trial 101 finished with value: 2.8783471174223023 and parameters: {'learning_rate': 0.0941917865655059, 'max_depth': 7, 'num_leaves': 10, 'min_child_samples': 17, 'lambda_l1': 24.24352718269148, 'lambda_l2': 17.165442986366216, 'feature_fraction': 0.6762451120774899, 'bagging_fraction': 0.7759023910835707, 'bagging_freq': 5, 'max_cat_threshold': 14}. Best is trial 88 with value: 2.8611023989967053.
# [I 2025-01-30 13:46:54,770] Trial 102 finished with value: 2.9144824254048878 and parameters: {'learning_rate': 0.08911590157201409, 'max_depth': 4, 'num_leaves': 9, 'min_child_samples': 22, 'lambda_l1': 13.423215435226414, 'lambda_l2': 8.256327724617547, 'feature_fraction': 0.635120106865781, 'bagging_fraction': 0.628014631276516, 'bagging_freq': 5, 'max_cat_threshold': 13}. Best is trial 88 with value: 2.8611023989967053.
# [I 2025-01-30 13:46:54,873] Trial 103 finished with value: 2.8767777046938567 and parameters: {'learning_rate': 0.08930097685394804, 'max_depth': 7, 'num_leaves': 10, 'min_child_samples': 17, 'lambda_l1': 24.441136500255062, 'lambda_l2': 10.53920968779991, 'feature_fraction': 0.6021692904011534, 'bagging_fraction': 0.7907351575955441, 'bagging_freq': 5, 'max_cat_threshold': 13}. Best is trial 88 with value: 2.8611023989967053.
# [I 2025-01-30 13:46:55,025] Trial 104 finished with value: 2.8790813956832704 and parameters: {'learning_rate': 0.09480166751072792, 'max_depth': 8, 'num_leaves': 10, 'min_child_samples': 17, 'lambda_l1': 21.352980429914577, 'lambda_l2': 10.608284533112009, 'feature_fraction': 0.6724190031116563, 'bagging_fraction': 0.7118727689262311, 'bagging_freq': 5, 'max_cat_threshold': 14}. Best is trial 88 with value: 2.8611023989967053.
# [I 2025-01-30 13:46:55,142] Trial 105 finished with value: 2.926260223587361 and parameters: {'learning_rate': 0.09101217034536209, 'max_depth': 7, 'num_leaves': 10, 'min_child_samples': 20, 'lambda_l1': 21.36285909309273, 'lambda_l2': 16.346009375674992, 'feature_fraction': 0.5988525009131964, 'bagging_fraction': 0.8322394676413694, 'bagging_freq': 4, 'max_cat_threshold': 14}. Best is trial 88 with value: 2.8611023989967053.
# [I 2025-01-30 13:46:55,292] Trial 106 finished with value: 2.9104733288151072 and parameters: {'learning_rate': 0.09038428848838641, 'max_depth': 8, 'num_leaves': 10, 'min_child_samples': 16, 'lambda_l1': 25.949526650111718, 'lambda_l2': 17.9261850452189, 'feature_fraction': 0.6778513325479597, 'bagging_fraction': 0.7651136164787194, 'bagging_freq': 5, 'max_cat_threshold': 14}. Best is trial 88 with value: 2.8611023989967053.
# [I 2025-01-30 13:46:55,395] Trial 107 finished with value: 3.1580685063379774 and parameters: {'learning_rate': 0.03451852052758249, 'max_depth': 7, 'num_leaves': 10, 'min_child_samples': 16, 'lambda_l1': 27.38089511396464, 'lambda_l2': 15.353638680411933, 'feature_fraction': 0.5663678078923134, 'bagging_fraction': 0.7784854638255335, 'bagging_freq': 5, 'max_cat_threshold': 13}. Best is trial 88 with value: 2.8611023989967053.
# [I 2025-01-30 13:46:55,553] Trial 108 finished with value: 3.184571020283859 and parameters: {'learning_rate': 0.03336927914012675, 'max_depth': 7, 'num_leaves': 10, 'min_child_samples': 15, 'lambda_l1': 28.272785710628632, 'lambda_l2': 14.90954291624041, 'feature_fraction': 0.5562468075316847, 'bagging_fraction': 0.7952193632200192, 'bagging_freq': 5, 'max_cat_threshold': 13}. Best is trial 88 with value: 2.8611023989967053.
# [I 2025-01-30 13:46:55,657] Trial 109 finished with value: 2.9043389026746236 and parameters: {'learning_rate': 0.0953842786687943, 'max_depth': 9, 'num_leaves': 10, 'min_child_samples': 17, 'lambda_l1': 23.82751300172118, 'lambda_l2': 41.57484728855324, 'feature_fraction': 0.7064709906108825, 'bagging_fraction': 0.7818841149220289, 'bagging_freq': 5, 'max_cat_threshold': 13}. Best is trial 88 with value: 2.8611023989967053.
# [I 2025-01-30 13:46:55,803] Trial 110 finished with value: 2.8916244961857047 and parameters: {'learning_rate': 0.095617107126086, 'max_depth': 7, 'num_leaves': 10, 'min_child_samples': 17, 'lambda_l1': 23.92509780601864, 'lambda_l2': 42.5524192356926, 'feature_fraction': 0.6650511020169583, 'bagging_fraction': 0.7118349850929196, 'bagging_freq': 6, 'max_cat_threshold': 17}. Best is trial 88 with value: 2.8611023989967053.
# ...
# [I 2025-01-30 13:48:00,192] Trial 463 finished with value: 2.8750394293994193 and parameters: {'learning_rate': 0.09992282480226534, 'max_depth': 6, 'num_leaves': 10, 'min_child_samples': 10, 'lambda_l1': 10.648703541596014, 'lambda_l2': 5.524782622661698, 'feature_fraction': 0.8511864440351187, 'bagging_fraction': 0.7624609977386603, 'bagging_freq': 13, 'max_cat_threshold': 27}. Best is trial 331 with value: 2.7857432475242123.
# [I 2025-01-30 13:48:00,410] Trial 464 finished with value: 2.8343197810641327 and parameters: {'learning_rate': 0.09249535683640682, 'max_depth': 6, 'num_leaves': 10, 'min_child_samples': 5, 'lambda_l1': 8.670497799825997, 'lambda_l2': 5.148008667402342, 'feature_fraction': 0.8583036609626628, 'bagging_fraction': 0.7788363579819436, 'bagging_freq': 2, 'max_cat_threshold': 27}. Best is trial 331 with value: 2.7857432475242123.
# [I 2025-01-30 13:48:00,596] Trial 465 finished with value: 2.809758001971357 and parameters: {'learning_rate': 0.09975946913117228, 'max_depth': 6, 'num_leaves': 10, 'min_child_samples': 11, 'lambda_l1': 12.291915863574644, 'lambda_l2': 8.401163490888296, 'feature_fraction': 0.8176632182160954, 'bagging_fraction': 0.7807792424429858, 'bagging_freq': 2, 'max_cat_threshold': 28}. Best is trial 331 with value: 2.7857432475242123.
# [I 2025-01-30 13:48:00,796] Trial 466 finished with value: 2.8904622330433503 and parameters: {'learning_rate': 0.09970172116891003, 'max_depth': 6, 'num_leaves': 10, 'min_child_samples': 11, 'lambda_l1': 12.687192897940703, 'lambda_l2': 49.38243490885367, 'feature_fraction': 0.8130452130795248, 'bagging_fraction': 0.792819404535206, 'bagging_freq': 2, 'max_cat_threshold': 29}. Best is trial 331 with value: 2.7857432475242123.
# [I 2025-01-30 13:48:00,941] Trial 467 finished with value: 2.96137906608154 and parameters: {'learning_rate': 0.09971319589377188, 'max_depth': 6, 'num_leaves': 10, 'min_child_samples': 11, 'lambda_l1': 12.042550624471504, 'lambda_l2': 8.561127069974198, 'feature_fraction': 0.19410451051723832, 'bagging_fraction': 0.8038733844509105, 'bagging_freq': 2, 'max_cat_threshold': 29}. Best is trial 331 with value: 2.7857432475242123.
# [I 2025-01-30 13:48:01,158] Trial 468 finished with value: 2.8850940368375313 and parameters: {'learning_rate': 0.09623276654638957, 'max_depth': 6, 'num_leaves': 10, 'min_child_samples': 8, 'lambda_l1': 7.245312005666232, 'lambda_l2': 7.70269243504604, 'feature_fraction': 0.3949380095750105, 'bagging_fraction': 0.8084702838609502, 'bagging_freq': 1, 'max_cat_threshold': 26}. Best is trial 331 with value: 2.7857432475242123.
# [I 2025-01-30 13:48:01,308] Trial 469 finished with value: 2.882962851341331 and parameters: {'learning_rate': 0.09570647958171032, 'max_depth': 6, 'num_leaves': 10, 'min_child_samples': 8, 'lambda_l1': 6.488077295922688, 'lambda_l2': 7.8664510525925975, 'feature_fraction': 0.794348113738846, 'bagging_fraction': 0.8178626964023019, 'bagging_freq': 1, 'max_cat_threshold': 28}. Best is trial 331 with value: 2.7857432475242123.
# [I 2025-01-30 13:48:01,540] Trial 470 finished with value: 2.839320511915894 and parameters: {'learning_rate': 0.09570385527704389, 'max_depth': 6, 'num_leaves': 10, 'min_child_samples': 12, 'lambda_l1': 9.71415343420012, 'lambda_l2': 7.796170420402181, 'feature_fraction': 0.7839772690917644, 'bagging_fraction': 0.7822280440175533, 'bagging_freq': 3, 'max_cat_threshold': 28}. Best is trial 331 with value: 2.7857432475242123.
# [I 2025-01-30 13:48:01,693] Trial 471 finished with value: 2.8163423840947313 and parameters: {'learning_rate': 0.0998151592088333, 'max_depth': 6, 'num_leaves': 10, 'min_child_samples': 12, 'lambda_l1': 9.495631213914319, 'lambda_l2': 6.434022423768434, 'feature_fraction': 0.7799157138147483, 'bagging_fraction': 0.7802708792298759, 'bagging_freq': 2, 'max_cat_threshold': 29}. Best is trial 331 with value: 2.7857432475242123.
# [I 2025-01-30 13:48:01,957] Trial 472 finished with value: 2.879876209769601 and parameters: {'learning_rate': 0.09194685016105755, 'max_depth': 6, 'num_leaves': 10, 'min_child_samples': 12, 'lambda_l1': 9.309982025198096, 'lambda_l2': 5.849889861597081, 'feature_fraction': 0.8203108241469976, 'bagging_fraction': 0.7384420494408839, 'bagging_freq': 2, 'max_cat_threshold': 29}. Best is trial 331 with value: 2.7857432475242123.
# [I 2025-01-30 13:48:02,098] Trial 473 finished with value: 2.85647961818219 and parameters: {'learning_rate': 0.09987885168095369, 'max_depth': 6, 'num_leaves': 10, 'min_child_samples': 12, 'lambda_l1': 8.965914496073161, 'lambda_l2': 6.721742186091533, 'feature_fraction': 0.8192189437016175, 'bagging_fraction': 0.7209700378404649, 'bagging_freq': 2, 'max_cat_threshold': 29}. Best is trial 331 with value: 2.7857432475242123.
# [I 2025-01-30 13:48:02,358] Trial 474 finished with value: 2.9008014998822413 and parameters: {'learning_rate': 0.09971441797957847, 'max_depth': 6, 'num_leaves': 10, 'min_child_samples': 10, 'lambda_l1': 8.394179741132916, 'lambda_l2': 6.041914305113949, 'feature_fraction': 0.8075444611155668, 'bagging_fraction': 0.7564527094727997, 'bagging_freq': 14, 'max_cat_threshold': 29}. Best is trial 331 with value: 2.7857432475242123.
# [I 2025-01-30 13:48:02,476] Trial 475 finished with value: 2.8694871285110306 and parameters: {'learning_rate': 0.09342621187087365, 'max_depth': 6, 'num_leaves': 10, 'min_child_samples': 7, 'lambda_l1': 10.180721610317292, 'lambda_l2': 9.726505691623341, 'feature_fraction': 0.8041132578331199, 'bagging_fraction': 0.7557097852248695, 'bagging_freq': 1, 'max_cat_threshold': 28}. Best is trial 331 with value: 2.7857432475242123.
# [I 2025-01-30 13:48:02,725] Trial 476 finished with value: 2.9085101554561437 and parameters: {'learning_rate': 0.09232455686394664, 'max_depth': 6, 'num_leaves': 7, 'min_child_samples': 10, 'lambda_l1': 10.444898411393295, 'lambda_l2': 8.390021319346962, 'feature_fraction': 0.8304173739118276, 'bagging_fraction': 0.7697190908216243, 'bagging_freq': 1, 'max_cat_threshold': 28}. Best is trial 331 with value: 2.7857432475242123.
# [I 2025-01-30 13:48:02,889] Trial 477 finished with value: 2.915073609762117 and parameters: {'learning_rate': 0.09046057875024034, 'max_depth': 6, 'num_leaves': 10, 'min_child_samples': 6, 'lambda_l1': 68.70282581006819, 'lambda_l2': 7.040544184124584, 'feature_fraction': 0.8395023290375999, 'bagging_fraction': 0.7774887825874764, 'bagging_freq': 3, 'max_cat_threshold': 28}. Best is trial 331 with value: 2.7857432475242123.
# [I 2025-01-30 13:48:03,121] Trial 478 finished with value: 2.8722657194475163 and parameters: {'learning_rate': 0.0890467693916829, 'max_depth': 6, 'num_leaves': 10, 'min_child_samples': 9, 'lambda_l1': 7.87329452166549, 'lambda_l2': 4.483995095379655, 'feature_fraction': 0.7796268405418045, 'bagging_fraction': 0.7897506958049353, 'bagging_freq': 2, 'max_cat_threshold': 29}. Best is trial 331 with value: 2.7857432475242123.
# [I 2025-01-30 13:48:03,248] Trial 479 finished with value: 2.828627222958793 and parameters: {'learning_rate': 0.09542977393247142, 'max_depth': 6, 'num_leaves': 10, 'min_child_samples': 9, 'lambda_l1': 5.851859006811583, 'lambda_l2': 4.605740394074463, 'feature_fraction': 0.7774914111081604, 'bagging_fraction': 0.7923622619406264, 'bagging_freq': 2, 'max_cat_threshold': 29}. Best is trial 331 with value: 2.7857432475242123.
# [I 2025-01-30 13:48:03,542] Trial 480 finished with value: 2.8541890290178045 and parameters: {'learning_rate': 0.09536208206484331, 'max_depth': 6, 'num_leaves': 10, 'min_child_samples': 11, 'lambda_l1': 5.866810653683123, 'lambda_l2': 9.470623688455754, 'feature_fraction': 0.7970638096662093, 'bagging_fraction': 0.7437311836259323, 'bagging_freq': 2, 'max_cat_threshold': 27}. Best is trial 331 with value: 2.7857432475242123.
# [I 2025-01-30 13:48:03,653] Trial 481 finished with value: 2.8323137969850682 and parameters: {'learning_rate': 0.09998149313355645, 'max_depth': 6, 'num_leaves': 10, 'min_child_samples': 11, 'lambda_l1': 7.167550414158439, 'lambda_l2': 4.923171559343142, 'feature_fraction': 0.7747712790103103, 'bagging_fraction': 0.7985936251392252, 'bagging_freq': 3, 'max_cat_threshold': 29}. Best is trial 331 with value: 2.7857432475242123.
# [I 2025-01-30 13:48:03,942] Trial 482 finished with value: 2.8454911040153172 and parameters: {'learning_rate': 0.09531223347264668, 'max_depth': 6, 'num_leaves': 10, 'min_child_samples': 8, 'lambda_l1': 4.4716344048285555, 'lambda_l2': 5.995488838158987, 'feature_fraction': 0.7705881155878542, 'bagging_fraction': 0.7965292552237018, 'bagging_freq': 2, 'max_cat_threshold': 29}. Best is trial 331 with value: 2.7857432475242123.
# [I 2025-01-30 13:48:04,051] Trial 483 finished with value: 2.8614579126496236 and parameters: {'learning_rate': 0.09506660053508395, 'max_depth': 6, 'num_leaves': 10, 'min_child_samples': 8, 'lambda_l1': 5.112144167372977, 'lambda_l2': 6.522651394764662, 'feature_fraction': 0.7554906543570312, 'bagging_fraction': 0.8232107517529283, 'bagging_freq': 2, 'max_cat_threshold': 29}. Best is trial 331 with value: 2.7857432475242123.
# [I 2025-01-30 13:48:04,378] Trial 484 finished with value: 3.4076466579020233 and parameters: {'learning_rate': 0.017156146757872647, 'max_depth': 6, 'num_leaves': 10, 'min_child_samples': 12, 'lambda_l1': 7.235933566041814, 'lambda_l2': 4.610650821338045, 'feature_fraction': 0.7480517467116, 'bagging_fraction': 0.8234556370784301, 'bagging_freq': 2, 'max_cat_threshold': 29}. Best is trial 331 with value: 2.7857432475242123.
# [I 2025-01-30 13:48:04,475] Trial 485 finished with value: 2.898948158187513 and parameters: {'learning_rate': 0.08909177071054633, 'max_depth': 6, 'num_leaves': 10, 'min_child_samples': 13, 'lambda_l1': 1.637725526781741, 'lambda_l2': 4.24522680670867, 'feature_fraction': 0.8299011497829206, 'bagging_fraction': 0.5356386946551537, 'bagging_freq': 2, 'max_cat_threshold': 28}. Best is trial 331 with value: 2.7857432475242123.
# [I 2025-01-30 13:48:04,770] Trial 486 finished with value: 2.879276652445514 and parameters: {'learning_rate': 0.08137533527974687, 'max_depth': 6, 'num_leaves': 10, 'min_child_samples': 10, 'lambda_l1': 2.6461507968150557, 'lambda_l2': 4.168418302901829, 'feature_fraction': 0.846374024659834, 'bagging_fraction': 0.768341927843828, 'bagging_freq': 3, 'max_cat_threshold': 28}. Best is trial 331 with value: 2.7857432475242123.
# [I 2025-01-30 13:48:04,925] Trial 487 finished with value: 2.833614856019724 and parameters: {'learning_rate': 0.09261327680855806, 'max_depth': 6, 'num_leaves': 10, 'min_child_samples': 10, 'lambda_l1': 6.171547670824756, 'lambda_l2': 8.692216471457849, 'feature_fraction': 0.8503065663720843, 'bagging_fraction': 0.7685206494494972, 'bagging_freq': 3, 'max_cat_threshold': 28}. Best is trial 331 with value: 2.7857432475242123.
# [I 2025-01-30 13:48:05,229] Trial 488 finished with value: 2.857235511396331 and parameters: {'learning_rate': 0.09262484890642425, 'max_depth': 6, 'num_leaves': 10, 'min_child_samples': 5, 'lambda_l1': 8.967280583225165, 'lambda_l2': 7.612677380393721, 'feature_fraction': 0.8136275360471765, 'bagging_fraction': 0.7840062629786843, 'bagging_freq': 2, 'max_cat_threshold': 29}. Best is trial 331 with value: 2.7857432475242123.
# [I 2025-01-30 13:48:05,342] Trial 489 finished with value: 3.627658502094292 and parameters: {'learning_rate': 0.013320061160957252, 'max_depth': 6, 'num_leaves': 10, 'min_child_samples': 7, 'lambda_l1': 8.45679001455932, 'lambda_l2': 7.1569101198280975, 'feature_fraction': 0.8081820634301122, 'bagging_fraction': 0.3896071105381615, 'bagging_freq': 2, 'max_cat_threshold': 29}. Best is trial 331 with value: 2.7857432475242123.
# [I 2025-01-30 13:48:05,609] Trial 490 finished with value: 2.824102193267639 and parameters: {'learning_rate': 0.09992201255891901, 'max_depth': 6, 'num_leaves': 10, 'min_child_samples': 7, 'lambda_l1': 11.288475680965474, 'lambda_l2': 6.1477079093059075, 'feature_fraction': 0.7879375988422987, 'bagging_fraction': 0.8056167973022834, 'bagging_freq': 2, 'max_cat_threshold': 29}. Best is trial 331 with value: 2.7857432475242123.
# [I 2025-01-30 13:48:05,697] Trial 491 finished with value: 2.91184074595253 and parameters: {'learning_rate': 0.09988044654703057, 'max_depth': 6, 'num_leaves': 10, 'min_child_samples': 12, 'lambda_l1': 3.504112831009875, 'lambda_l2': 39.50336014597528, 'feature_fraction': 0.2937719746601113, 'bagging_fraction': 0.8078036862361504, 'bagging_freq': 2, 'max_cat_threshold': 27}. Best is trial 331 with value: 2.7857432475242123.
# [I 2025-01-30 13:48:06,025] Trial 492 finished with value: 3.0908332684595137 and parameters: {'learning_rate': 0.09995999160659554, 'max_depth': 6, 'num_leaves': 8, 'min_child_samples': 6, 'lambda_l1': 5.8925691493204955, 'lambda_l2': 6.352701495605967, 'feature_fraction': 0.7831962048814093, 'bagging_fraction': 0.1027956206206781, 'bagging_freq': 2, 'max_cat_threshold': 27}. Best is trial 331 with value: 2.7857432475242123.
# [I 2025-01-30 13:48:06,162] Trial 493 finished with value: 2.8402651701668473 and parameters: {'learning_rate': 0.09973681379107266, 'max_depth': 5, 'num_leaves': 10, 'min_child_samples': 6, 'lambda_l1': 5.923314929409703, 'lambda_l2': 6.073133028282218, 'feature_fraction': 0.7842648805919554, 'bagging_fraction': 0.8073752476368817, 'bagging_freq': 2, 'max_cat_threshold': 28}. Best is trial 331 with value: 2.7857432475242123.
# [I 2025-01-30 13:48:06,442] Trial 494 finished with value: 2.887502140949406 and parameters: {'learning_rate': 0.09581216004168815, 'max_depth': 6, 'num_leaves': 10, 'min_child_samples': 7, 'lambda_l1': 11.557368289039978, 'lambda_l2': 9.23324939655822, 'feature_fraction': 0.7863915361411137, 'bagging_fraction': 0.8502610301716406, 'bagging_freq': 2, 'max_cat_threshold': 28}. Best is trial 331 with value: 2.7857432475242123.
# [I 2025-01-30 13:48:06,574] Trial 495 finished with value: 2.8583564893518787 and parameters: {'learning_rate': 0.09999353302619948, 'max_depth': 6, 'num_leaves': 10, 'min_child_samples': 7, 'lambda_l1': 11.453515460205884, 'lambda_l2': 45.3535761860492, 'feature_fraction': 0.7581245649027151, 'bagging_fraction': 0.8417456041577466, 'bagging_freq': 2, 'max_cat_threshold': 29}. Best is trial 331 with value: 2.7857432475242123.
# [I 2025-01-30 13:48:06,834] Trial 496 finished with value: 3.163268761121999 and parameters: {'learning_rate': 0.08808692969572234, 'max_depth': 6, 'num_leaves': 10, 'min_child_samples': 6, 'lambda_l1': 10.101548448985882, 'lambda_l2': 44.64461078286139, 'feature_fraction': 0.11832123066760275, 'bagging_fraction': 0.8352128182424761, 'bagging_freq': 2, 'max_cat_threshold': 29}. Best is trial 331 with value: 2.7857432475242123.
# [I 2025-01-30 13:48:06,991] Trial 497 finished with value: 2.852864824605696 and parameters: {'learning_rate': 0.08665122685433765, 'max_depth': 6, 'num_leaves': 10, 'min_child_samples': 8, 'lambda_l1': 9.818051772839366, 'lambda_l2': 3.8020499798394023, 'feature_fraction': 0.7419232456035584, 'bagging_fraction': 0.7321440537496195, 'bagging_freq': 3, 'max_cat_threshold': 29}. Best is trial 331 with value: 2.7857432475242123.
# [I 2025-01-30 13:48:07,365] Trial 498 finished with value: 2.9162669858091057 and parameters: {'learning_rate': 0.09583405287826124, 'max_depth': 6, 'num_leaves': 10, 'min_child_samples': 8, 'lambda_l1': 18.033461968323415, 'lambda_l2': 3.765846755353829, 'feature_fraction': 0.8274239820373429, 'bagging_fraction': 0.7535530031115932, 'bagging_freq': 7, 'max_cat_threshold': 24}. Best is trial 331 with value: 2.7857432475242123.
# [I 2025-01-30 13:48:07,401] Trial 499 finished with value: 2.8740105163591894 and parameters: {'learning_rate': 0.09519475343164142, 'max_depth': 6, 'num_leaves': 10, 'min_child_samples': 5, 'lambda_l1': 17.910240683428004, 'lambda_l2': 3.1186475294269442, 'feature_fraction': 0.8284575967141864, 'bagging_fraction': 0.7553276868444377, 'bagging_freq': 7, 'max_cat_threshold': 28}. Best is trial 331 with value: 2.7857432475242123.

# %%
# Get best parameters and scores
best_params = study.best_params
best_value = study.best_value

print("Best parameters:", best_params)
print("Best CV score:", best_value)
print("Number of finished trials:", len(study.trials))
# Out:
# Best parameters: {'learning_rate': 0.0999708881316216, 'max_depth': 6, 'num_leaves': 10, 'min_child_samples': 13, 'lambda_l1': 10.904410483198347, 'lambda_l2': 3.242470744730208, 'feature_fraction': 0.7749319979298157, 'bagging_fraction': 0.7906446132738943, 'bagging_freq': 2, 'max_cat_threshold': 27}
# Best CV score: 2.7857432475242123
# Number of finished trials: 500

# %%
# Create importance plot
optuna.visualization.plot_param_importances(study)

# %%
params={"objective": "regression",
        "metric": "mae",
        "verbosity": -1,
        "boosting_type": "gbdt",
        "feature_pre_filter": False,
'learning_rate': 0.0999708881316216, 'max_depth': 6, 'num_leaves': 10, 'min_child_samples': 13, 'lambda_l1': 10.904410483198347, 'lambda_l2': 3.242470744730208, 'feature_fraction': 0.7749319979298157, 'bagging_fraction': 0.7906446132738943, 'bagging_freq': 2, 'max_cat_threshold': 27,
        "seed" : 42,
}

# %%
#Train a LightGBM model with tuned hyperparameters
dtrain = lgb.Dataset(X_train, label=y_train)

lgbfit = lgb.train(params,
                   dtrain,
                   num_boost_round=100
                   )

y_pred = lgbfit.predict(X_test)

mae_log = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print(f"Mean Absolute Error (log scale): {mae_log}")
print(f"R-squared: {r2}")
print(f"Train MAE: {mean_absolute_error(y_train, lgbfit.predict(X_train))}")
print(f"R-squared: {r2_score(y_train, lgbfit.predict(X_train))}")
# Out:
# Mean Absolute Error (log scale): 2.7857432475242123
# R-squared: 0.7031699572495941
# Train MAE: 2.283160712008541
# R-squared: 0.7925563056901855

# %% [markdown]
# After Tunning Hyperparameters we have reduced overfit significantly, thus making our model a lot more robust on unseen data.

# %%
lgbfit.save_model('lgbfit_new.txt')

# %%
#Determining How Much A Feature Contributes to Error between Predictions and Target Based On Shapley Values
def get_preds_shaps(df, features, target, ix_trn):
  dtrain = lgb.Dataset(df.loc[ix_trn, features], label=df.loc[ix_trn, target])
  model = lgb.train(params, dtrain, num_boost_round = 1000)
  preds = pd.Series(model.predict(df[features]), index=df.index)
  shap_explainer = shap.TreeExplainer(model)
  shaps = pd.DataFrame(
    data=shap_explainer.shap_values(df[features]),
    index=df.index,
    columns=features)
  return preds, shaps

def get_feature_contributions(y_true, y_pred, shap_values):
  """Compute prediction contribution and error contribution for each feature."""

  prediction_contribution = shap_values.abs().mean().rename("prediction_contribution")

  abs_error = (y_true - y_pred).abs()
  y_pred_wo_feature = shap_values.apply(lambda feature: y_pred - feature)
  abs_error_wo_feature = y_pred_wo_feature.apply(lambda feature: (y_true - feature).abs())
  error_contribution = abs_error_wo_feature.apply(lambda feature: abs_error - feature).mean().rename("error_contribution")
      
  return prediction_contribution, error_contribution

# %%
preds, shaps = get_preds_shaps(df=preprocessed_df, features=features, target=target, ix_trn=ix_trn)

prediction_contribution_trn, error_contribution_trn = get_feature_contributions(
  y_true=preprocessed_df.loc[ix_trn, target], 
  y_pred=preds.loc[ix_trn], 
  shap_values=shaps.loc[ix_trn, :]
)

prediction_contribution_val, error_contribution_val = get_feature_contributions(
  y_true=preprocessed_df.loc[ix_val, target], 
  y_pred=preds.loc[ix_val], 
  shap_values=shaps.loc[ix_val, :]
)
contributions_trn = pd.concat([prediction_contribution_trn, error_contribution_trn], axis=1)
contributions_val = pd.concat([prediction_contribution_val, error_contribution_val], axis=1)

# %%
pd.set_option("display.max_rows", 10)

contributions_trn.sort_values("prediction_contribution", ascending=False).round(4).head(10)
# Out:
#                                          prediction_contribution  \
# 7_NDVI                                                    3.1059
# Агрофон_Fallow                                            0.7541
# MAX_NDVI                                                  0.7421
# phh2o                                                     0.4125
# sand                                                      0.3995
# soc                                                       0.3849
# 8_total_precipitation_sum                                 0.3466
# 5_surface_solar_radiation_downwards_sum                   0.3364
# DOY_max                                                   0.3286
# clay                                                      0.3149
#
#                                          error_contribution
# 7_NDVI                                              -2.3290
# Агрофон_Fallow                                      -0.2360
# MAX_NDVI                                            -0.3204
# phh2o                                               -0.1356
# sand                                                -0.1528
# soc                                                 -0.1617
# 8_total_precipitation_sum                           -0.0895
# 5_surface_solar_radiation_downwards_sum             -0.0666
# DOY_max                                             -0.1068
# clay                                                -0.1089

# %%
pd.set_option("display.max_rows", 30)

contributions_val.sort_values("error_contribution", ascending=True).round(4).head(10)
# Out:
#                                          prediction_contribution  \
# 7_NDVI                                                    3.0408
# MAX_NDVI                                                  0.7566
# Агрофон_Fallow                                            0.7411
# DOY_min                                                   0.2565
# 8_v_component_of_wind_10m                                 0.2669
# 6_surface_solar_radiation_downwards_sum                   0.2711
# 8_surface_solar_radiation_downwards_sum                   0.3021
# DOY_max                                                   0.3083
# 8_temperature_2m_min                                      0.1959
# 5_surface_solar_radiation_downwards_sum                   0.3388
#
#                                          error_contribution
# 7_NDVI                                              -1.3661
# MAX_NDVI                                            -0.1060
# Агрофон_Fallow                                      -0.0660
# DOY_min                                             -0.0416
# 8_v_component_of_wind_10m                           -0.0388
# 6_surface_solar_radiation_downwards_sum             -0.0359
# 8_surface_solar_radiation_downwards_sum             -0.0351
# DOY_max                                             -0.0332
# 8_temperature_2m_min                                -0.0219
# 5_surface_solar_radiation_downwards_sum             -0.0178

# %%
pd.set_option("display.max_rows", 30)

contributions_val.sort_values("error_contribution", ascending=False).round(4).head(10)
# Out:
#                            prediction_contribution  error_contribution
# 6_v_component_of_wind_10m                   0.1869              0.0168
# silt                                        0.2430              0.0154
# sand                                        0.4031              0.0131
# 8_vapor_pressure_deficit                    0.1748              0.0095
# 8_relative_humidity                         0.1571              0.0087
# cec                                         0.2235              0.0083
# 7_v_component_of_wind_10m                   0.1067              0.0049
# 5_total_precipitation_sum                   0.1482              0.0036
# phh2o                                       0.4108              0.0031
# 6_temperature_2m_max                        0.0857              0.0029

# %% [markdown]
# We can see again that excluding 7_NDVI has strong negative contributions to the prediction accuracy of our model thus cementing once more how important of a feature it is to the model. Whearas the features that contributes the most to error is June Wind Speed, however the contribution is very small or neglegible
